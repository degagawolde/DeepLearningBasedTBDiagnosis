# %%
import os
import datetime
import time
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Conv2D, Activation, BatchNormalization,MaxPooling2D,Dense,concatenate
from tensorflow.keras.layers import UpSampling2D, Input, Concatenate,Conv2DTranspose
from tensorflow.keras.layers import Input,UpSampling3D,Dense, Dropout,BatchNormalization, Activation
from tensorflow.keras.layers import GlobalAveragePooling2D, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint,LearningRateScheduler
from tensorflow.keras.metrics import Recall, Precision,MeanIoU,AUC
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
IMAGE_SIZE = 256
EPOCHS = 50
BATCH = 4
LR = 1e-4

PATH = '../../dataset/LSP/train/'

# %%
def load_data(path='../dataset/LSP/train/', split=0.1,mode=''):
    images = sorted(glob(os.path.join(path, "images/*")))
    masks = sorted(glob(os.path.join(path, "masks/*")))
    
    if mode == 'training':
        total_size = len(images)
        valid_size = int(split * total_size)
        train_x, valid_x = train_test_split(images, test_size=valid_size, random_state=42)
        train_y, valid_y = train_test_split(masks, test_size=valid_size, random_state=42)

        return (train_x, train_y), (valid_x, valid_y)
    
    if mode == 'testing':
        return (images,masks)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (256, 256))
    x = x/255.0
    x = np.expand_dims(x, axis=-1)
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
    x.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    y.set_shape([256, 256, 1])
    return x, y

def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
#     dataset = dataset.repeat()
    return dataset

# %%
(train_x, train_y), (valid_x, valid_y) = load_data(PATH,mode='training')

print("Training data: ", len(train_x))
print("Validation data: ", len(valid_x))
# Out:
# Training data:  1359
# Validation data:  150

# %%
def read_and_rgb(x):
    x = cv2.imread(x)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    return x

# %%
fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(valid_x[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(valid_x[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(valid_x[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(valid_x[3]))
imgplot.set_clim(0.0, 2.1)

fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(valid_y[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(valid_y[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(valid_y[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(valid_y[3]))
imgplot.set_clim(0.0, 1.4)

# %%
def build_model(inputs):
    mobilenetv2 = tf.keras.applications.MobileNetV2(
        input_tensor = inputs, 
        weights="imagenet", include_top=False, alpha=0.35)
    
    x = mobilenetv2.get_layer('out_relu').output
    x = Conv2D(128,3,name='final_conv',padding='same',activation='relu')(x)
    x = GlobalAveragePooling2D(name='gap')(x)
    output = Dense(2,activation='sigmoid')(x)
    return tf.keras.Model(inputs,output)

# %%
def model():
    inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")
    
    encoder = build_model(inputs)
#     encoder.load_weights('../../output/checkpoints/mobilenetv2/512_128weights.16-0.31.hdf5')
    skip_connection_names = ["input_image","block_1_expand_relu", "block_3_expand_relu", "block_6_expand_relu"]
    encoder_output = encoder.get_layer("block_13_expand_relu").output
    
    f = [ 16, 32, 48, 64,64]
    x = encoder_output
    for i in range(1, len(skip_connection_names)+1, 1):
        x_skip = encoder.get_layer(skip_connection_names[-i]).output
        x = UpSampling2D((2, 2))(x)
        x = Concatenate()([x, x_skip])
        
        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        
        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        
    x = Conv2D(1, (1, 1), padding="same")(x)
    x = Activation("sigmoid")(x)
    
    model = Model(inputs, x)
    return model

# %%
model = model()
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Metal device set to: Apple M1
# 2022-06-10 23:02:13.231405: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-10 23:02:13.231498: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 128, 128, 16) 432         input_image[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 128, 128, 16) 64          Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 128, 128, 16) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 128, 128, 16) 144         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 128, 128, 16) 64          expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 128, 128, 16) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 128, 128, 8)  128         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 128, 128, 8)  32          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 128, 128, 48) 384         expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 128, 128, 48) 192         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 128, 128, 48) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 129, 129, 48) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 64, 64, 48)   432         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 64, 64, 48)   192         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 64, 64, 48)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 64, 64, 8)    384         block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 64, 64, 8)    32          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 64, 64, 48)   384         block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 64, 64, 48)   192         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 64, 64, 48)   0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 64, 64, 48)   432         block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 64, 64, 48)   192         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 64, 64, 48)   0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 64, 64, 8)    384         block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 64, 64, 8)    32          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 64, 64, 8)    0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 64, 64, 48)   384         block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 64, 64, 48)   192         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 64, 64, 48)   0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 65, 65, 48)   0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 32, 32, 48)   432         block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 32, 32, 48)   192         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 32, 32, 48)   0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 32, 32, 16)   768         block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 32, 32, 16)   64          block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 32, 32, 96)   1536        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 32, 32, 96)   384         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 32, 32, 96)   0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 32, 32, 96)   864         block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 32, 32, 96)   384         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 32, 32, 96)   0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 32, 32, 16)   1536        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 32, 32, 16)   64          block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 32, 32, 16)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 32, 32, 96)   1536        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 32, 32, 96)   384         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 32, 32, 96)   0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 32, 32, 96)   864         block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 32, 32, 96)   384         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 32, 32, 96)   0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 32, 32, 16)   1536        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 32, 32, 16)   64          block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 32, 32, 16)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 32, 32, 96)   1536        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 32, 32, 96)   384         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 32, 32, 96)   0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 33, 33, 96)   0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 16, 16, 96)   864         block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 16, 16, 96)   384         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 16, 16, 96)   0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 16, 16, 24)   2304        block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 16, 16, 24)   96          block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 16, 16, 144)  3456        block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 16, 16, 144)  576         block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 16, 16, 144)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 16, 16, 144)  1296        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 16, 16, 144)  576         block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 16, 16, 144)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 16, 16, 24)   3456        block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 16, 16, 24)   96          block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 16, 16, 24)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 16, 16, 144)  3456        block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 16, 16, 144)  576         block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 16, 16, 144)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 16, 16, 144)  1296        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 16, 16, 144)  576         block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 16, 16, 144)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 16, 16, 24)   3456        block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 16, 16, 24)   96          block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 16, 16, 24)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 16, 16, 144)  3456        block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 16, 16, 144)  576         block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 16, 16, 144)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 16, 16, 144)  1296        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 16, 16, 144)  576         block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 16, 16, 144)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 16, 16, 24)   3456        block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 16, 16, 24)   96          block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 16, 16, 24)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 16, 16, 144)  3456        block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 16, 16, 144)  576         block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 16, 16, 144)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 16, 16, 144)  1296        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 16, 16, 144)  576         block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 16, 16, 144)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 16, 16, 32)   4608        block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 16, 16, 32)   128         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 16, 16, 192)  6144        block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 16, 16, 192)  768         block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 16, 16, 192)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 16, 16, 192)  1728        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 16, 16, 192)  768         block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 16, 16, 192)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 16, 16, 32)   6144        block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 16, 16, 32)   128         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 16, 16, 32)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 16, 16, 192)  6144        block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 16, 16, 192)  768         block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 16, 16, 192)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 16, 16, 192)  1728        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 16, 16, 192)  768         block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 16, 16, 192)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 16, 16, 32)   6144        block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 16, 16, 32)   128         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 16, 16, 32)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 16, 16, 192)  6144        block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 16, 16, 192)  768         block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 16, 16, 192)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 192)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 288)  0           up_sampling2d[0][0]
#                                                                  block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   165952      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 112)  0           up_sampling2d_1[0][0]
#                                                                  block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   64576       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 64) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 112 0           up_sampling2d_2[0][0]
#                                                                  block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 48) 48432       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 48) 192         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128, 128, 48) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 48) 20784       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 48) 192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 48) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 48) 0           activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 51) 0           up_sampling2d_3[0][0]
#                                                                  input_image[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 256, 32) 14720       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 256, 256, 32) 128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 256, 256, 32) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 32) 9248        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 256, 256, 32) 128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 256, 256, 32) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 1)  33          activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256, 256, 1)  0           conv2d_8[0][0]
# ==================================================================================================
# Total params: 497,777
# Trainable params: 490,401
# Non-trainable params: 7,376
# __________________________________________________________________________________________________

# %%
smooth = 1
def dice_coef(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(y_true * y_pred)
    return (2. * intersection + smooth) / (K.sum(y_true) + K.sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
train_dataset = tf_dataset(train_x, train_y, batch=BATCH)
valid_dataset = tf_dataset(valid_x, valid_y, batch=BATCH)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function tf_parse at 0x2878cbf70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function tf_parse at 0x2878cbf70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
opt = tf.keras.optimizers.Nadam(LR)
metrics = [dice_coef, MeanIoU(num_classes=2), AUC(curve='PR'), Recall(), Precision()]
model.compile(loss = dice_loss, optimizer=opt, metrics=metrics)

# %%
log_dir = "logs/unet/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3),
    tf.keras.callbacks.TensorBoard(log_dir=log_dir),
    ModelCheckpoint(
        '../../output/checkpoints/mobilenetv2/unet_weights.{epoch:02d}.{val_loss:.2f}.hdf5',
        monitor='val_loss',save_best_only=True,save_weights_only=True,verbose=1),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False)
]
# Out:
# 2022-06-10 23:02:13.903663: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session initializing.
# 2022-06-10 23:02:13.903673: I tensorflow/core/profiler/lib/profiler_session.cc:141] Profiler session started.
# 2022-06-10 23:02:13.903887: I tensorflow/core/profiler/lib/profiler_session.cc:159] Profiler session tear down.

# %%
train_steps = len(train_x)//BATCH
valid_steps = len(valid_x)//BATCH

if len(train_x) % BATCH != 0:
    train_steps += 1
if len(valid_x) % BATCH != 0:
    valid_steps += 1

model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    steps_per_epoch=train_steps,
    validation_steps=valid_steps,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x2bc11a820> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x2bc11a820> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# /Users/user/miniforge3/envs/Apple/lib/python3.9/site-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# 2022-06-10 23:02:14.093849: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-06-10 23:02:14.093955: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# WARNING:tensorflow:AutoGraph could not transform <function dice_loss at 0x28e801af0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function dice_loss at 0x28e801af0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function dice_coef at 0x28e801700> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function dice_coef at 0x28e801700> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2022-06-10 23:02:16.551028: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
#   1/340 [..............................] - ETA: 29:33 - loss: 0.6373 - dice_coef: 0.3627 - mean_io_u: 0.3428 - auc: 0.3293 - recall: 0.4170 - precision: 0.2780
# 2022-06-10 23:02:19.446101: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session initializing.
# 2022-06-10 23:02:19.446119: I tensorflow/core/profiler/lib/profiler_session.cc:141] Profiler session started.
#   2/340 [..............................] - ETA: 6:34 - loss: 0.6244 - dice_coef: 0.3756 - mean_io_u: 0.3411 - auc: 0.3492 - recall: 0.4386 - precision: 0.3083
# 2022-06-10 23:02:20.497841: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-06-10 23:02:20.499571: I tensorflow/core/profiler/lib/profiler_session.cc:159] Profiler session tear down.
# 2022-06-10 23:02:20.501227: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs/unet/20220610-230213/train/plugins/profile/2022_06_10_23_02_20
# 2022-06-10 23:02:20.502741: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for trace.json.gz to logs/unet/20220610-230213/train/plugins/profile/2022_06_10_23_02_20/users-MBP.trace.json.gz
# 2022-06-10 23:02:20.504504: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs/unet/20220610-230213/train/plugins/profile/2022_06_10_23_02_20
# 2022-06-10 23:02:20.504635: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for memory_profile.json.gz to logs/unet/20220610-230213/train/plugins/profile/2022_06_10_23_02_20/users-MBP.memory_profile.json.gz
# 2022-06-10 23:02:20.505059: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: logs/unet/20220610-230213/train/plugins/profile/2022_06_10_23_02_20Dumped tool data for xplane.pb to logs/unet/20220610-230213/train/plugins/profile/2022_06_10_23_02_20/users-MBP.xplane.pb
# Dumped tool data for overview_page.pb to logs/unet/20220610-230213/train/plugins/profile/2022_06_10_23_02_20/users-MBP.overview_page.pb
# Dumped tool data for input_pipeline.pb to logs/unet/20220610-230213/train/plugins/profile/2022_06_10_23_02_20/users-MBP.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to logs/unet/20220610-230213/train/plugins/profile/2022_06_10_23_02_20/users-MBP.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to logs/unet/20220610-230213/train/plugins/profile/2022_06_10_23_02_20/users-MBP.kernel_stats.pb
# 340/340 [==============================] - ETA: 0s - loss: 0.1454 - dice_coef: 0.8546 - mean_io_u: 0.3449 - auc: 0.9789 - recall: 0.9523 - precision: 0.9095WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x2bc1a8f70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x2bc1a8f70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2022-06-10 23:08:33.510356: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 340/340 [==============================] - 413s 1s/step - loss: 0.1454 - dice_coef: 0.8546 - mean_io_u: 0.3449 - auc: 0.9789 - recall: 0.9523 - precision: 0.9095 - val_loss: 0.1383 - val_dice_coef: 0.8615 - val_mean_io_u: 0.3489 - val_auc: 0.9821 - val_recall: 0.9172 - val_precision: 0.9752
#
# Epoch 00001: val_loss improved from inf to 0.13834, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.01.0.14.hdf5
# Epoch 2/50
# 340/340 [==============================] - 409s 1s/step - loss: 0.0776 - dice_coef: 0.9224 - mean_io_u: 0.3449 - auc: 0.9859 - recall: 0.9698 - precision: 0.9610 - val_loss: 0.0829 - val_dice_coef: 0.9168 - val_mean_io_u: 0.3489 - val_auc: 0.9883 - val_recall: 0.9622 - val_precision: 0.9561
#
# Epoch 00002: val_loss improved from 0.13834 to 0.08290, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.02.0.08.hdf5
# Epoch 3/50
# 340/340 [==============================] - 410s 1s/step - loss: 0.0589 - dice_coef: 0.9411 - mean_io_u: 0.3449 - auc: 0.9859 - recall: 0.9702 - precision: 0.9674 - val_loss: 0.0645 - val_dice_coef: 0.9351 - val_mean_io_u: 0.3489 - val_auc: 0.9869 - val_recall: 0.9651 - val_precision: 0.9579
#
# Epoch 00003: val_loss improved from 0.08290 to 0.06451, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.03.0.06.hdf5
# Epoch 4/50
# 340/340 [==============================] - 409s 1s/step - loss: 0.0481 - dice_coef: 0.9519 - mean_io_u: 0.3449 - auc: 0.9855 - recall: 0.9707 - precision: 0.9706 - val_loss: 0.0535 - val_dice_coef: 0.9461 - val_mean_io_u: 0.3489 - val_auc: 0.9821 - val_recall: 0.9706 - val_precision: 0.9569
#
# Epoch 00004: val_loss improved from 0.06451 to 0.05351, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.04.0.05.hdf5
# Epoch 5/50
# 340/340 [==============================] - 413s 1s/step - loss: 0.0413 - dice_coef: 0.9587 - mean_io_u: 0.3449 - auc: 0.9848 - recall: 0.9711 - precision: 0.9728 - val_loss: 0.0461 - val_dice_coef: 0.9535 - val_mean_io_u: 0.3489 - val_auc: 0.9804 - val_recall: 0.9715 - val_precision: 0.9605
#
# Epoch 00005: val_loss improved from 0.05351 to 0.04606, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.05.0.05.hdf5
# Epoch 6/50
# 340/340 [==============================] - 412s 1s/step - loss: 0.0368 - dice_coef: 0.9632 - mean_io_u: 0.3449 - auc: 0.9843 - recall: 0.9715 - precision: 0.9743 - val_loss: 0.0423 - val_dice_coef: 0.9572 - val_mean_io_u: 0.3489 - val_auc: 0.9780 - val_recall: 0.9709 - val_precision: 0.9620
#
# Epoch 00006: val_loss improved from 0.04606 to 0.04233, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.06.0.04.hdf5
# Epoch 7/50
# 340/340 [==============================] - 410s 1s/step - loss: 0.0335 - dice_coef: 0.9665 - mean_io_u: 0.3449 - auc: 0.9836 - recall: 0.9721 - precision: 0.9756 - val_loss: 0.0392 - val_dice_coef: 0.9604 - val_mean_io_u: 0.3489 - val_auc: 0.9803 - val_recall: 0.9633 - val_precision: 0.9713
#
# Epoch 00007: val_loss improved from 0.04233 to 0.03917, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.07.0.04.hdf5
# Epoch 8/50
# 340/340 [==============================] - 409s 1s/step - loss: 0.0310 - dice_coef: 0.9690 - mean_io_u: 0.3449 - auc: 0.9832 - recall: 0.9726 - precision: 0.9768 - val_loss: 0.0392 - val_dice_coef: 0.9603 - val_mean_io_u: 0.3489 - val_auc: 0.9762 - val_recall: 0.9629 - val_precision: 0.9690
#
# Epoch 00008: val_loss did not improve from 0.03917
# Epoch 9/50
# 340/340 [==============================] - 411s 1s/step - loss: 0.0291 - dice_coef: 0.9709 - mean_io_u: 0.3449 - auc: 0.9828 - recall: 0.9730 - precision: 0.9777 - val_loss: 0.0382 - val_dice_coef: 0.9614 - val_mean_io_u: 0.3489 - val_auc: 0.9760 - val_recall: 0.9559 - val_precision: 0.9757
#
# Epoch 00009: val_loss improved from 0.03917 to 0.03817, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.09.0.04.hdf5
# Epoch 10/50
# 340/340 [==============================] - 411s 1s/step - loss: 0.0276 - dice_coef: 0.9724 - mean_io_u: 0.3449 - auc: 0.9823 - recall: 0.9734 - precision: 0.9785 - val_loss: 0.0382 - val_dice_coef: 0.9613 - val_mean_io_u: 0.3489 - val_auc: 0.9745 - val_recall: 0.9527 - val_precision: 0.9775
#
# Epoch 00010: val_loss improved from 0.03817 to 0.03816, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.10.0.04.hdf5
# Epoch 11/50
# 340/340 [==============================] - 411s 1s/step - loss: 0.0262 - dice_coef: 0.9738 - mean_io_u: 0.3449 - auc: 0.9819 - recall: 0.9741 - precision: 0.9792 - val_loss: 0.0374 - val_dice_coef: 0.9621 - val_mean_io_u: 0.3489 - val_auc: 0.9716 - val_recall: 0.9567 - val_precision: 0.9739
#
# Epoch 00011: val_loss improved from 0.03816 to 0.03737, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.11.0.04.hdf5
# Epoch 12/50
# 340/340 [==============================] - 411s 1s/step - loss: 0.0252 - dice_coef: 0.9748 - mean_io_u: 0.3449 - auc: 0.9816 - recall: 0.9746 - precision: 0.9798 - val_loss: 0.0362 - val_dice_coef: 0.9633 - val_mean_io_u: 0.3489 - val_auc: 0.9673 - val_recall: 0.9671 - val_precision: 0.9654
#
# Epoch 00012: val_loss improved from 0.03737 to 0.03621, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.12.0.04.hdf5
# Epoch 13/50
# 340/340 [==============================] - 409s 1s/step - loss: 0.0241 - dice_coef: 0.9759 - mean_io_u: 0.3449 - auc: 0.9814 - recall: 0.9751 - precision: 0.9806 - val_loss: 0.0369 - val_dice_coef: 0.9626 - val_mean_io_u: 0.3489 - val_auc: 0.9690 - val_recall: 0.9568 - val_precision: 0.9734
#
# Epoch 00013: val_loss did not improve from 0.03621
# Epoch 14/50
# 340/340 [==============================] - 411s 1s/step - loss: 0.0233 - dice_coef: 0.9767 - mean_io_u: 0.3449 - auc: 0.9812 - recall: 0.9757 - precision: 0.9810 - val_loss: 0.0362 - val_dice_coef: 0.9633 - val_mean_io_u: 0.3489 - val_auc: 0.9676 - val_recall: 0.9577 - val_precision: 0.9733
#
# Epoch 00014: val_loss improved from 0.03621 to 0.03618, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.14.0.04.hdf5
# Epoch 15/50
# 340/340 [==============================] - 412s 1s/step - loss: 0.0224 - dice_coef: 0.9776 - mean_io_u: 0.3449 - auc: 0.9813 - recall: 0.9764 - precision: 0.9817 - val_loss: 0.0368 - val_dice_coef: 0.9627 - val_mean_io_u: 0.3489 - val_auc: 0.9622 - val_recall: 0.9666 - val_precision: 0.9635
#
# Epoch 00015: val_loss did not improve from 0.03618
# Epoch 16/50
# 340/340 [==============================] - 412s 1s/step - loss: 0.0216 - dice_coef: 0.9784 - mean_io_u: 0.3449 - auc: 0.9821 - recall: 0.9770 - precision: 0.9823 - val_loss: 0.0344 - val_dice_coef: 0.9651 - val_mean_io_u: 0.3489 - val_auc: 0.9664 - val_recall: 0.9647 - val_precision: 0.9697
#
# Epoch 00016: val_loss improved from 0.03618 to 0.03442, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.16.0.03.hdf5
# Epoch 17/50
# 340/340 [==============================] - 3112s 9s/step - loss: 0.0212 - dice_coef: 0.9788 - mean_io_u: 0.3449 - auc: 0.9823 - recall: 0.9775 - precision: 0.9827 - val_loss: 0.0341 - val_dice_coef: 0.9654 - val_mean_io_u: 0.3489 - val_auc: 0.9668 - val_recall: 0.9645 - val_precision: 0.9705
#
# Epoch 00017: val_loss improved from 0.03442 to 0.03413, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.17.0.03.hdf5
# Epoch 18/50
# 340/340 [==============================] - 2119s 6s/step - loss: 0.0209 - dice_coef: 0.9791 - mean_io_u: 0.3449 - auc: 0.9824 - recall: 0.9777 - precision: 0.9829 - val_loss: 0.0339 - val_dice_coef: 0.9656 - val_mean_io_u: 0.3489 - val_auc: 0.9670 - val_recall: 0.9645 - val_precision: 0.9710
#
# Epoch 00018: val_loss improved from 0.03413 to 0.03389, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.18.0.03.hdf5
# Epoch 19/50
# 340/340 [==============================] - 410s 1s/step - loss: 0.0207 - dice_coef: 0.9793 - mean_io_u: 0.3449 - auc: 0.9825 - recall: 0.9779 - precision: 0.9830 - val_loss: 0.0337 - val_dice_coef: 0.9658 - val_mean_io_u: 0.3489 - val_auc: 0.9671 - val_recall: 0.9645 - val_precision: 0.9713
#
# Epoch 00019: val_loss improved from 0.03389 to 0.03370, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.19.0.03.hdf5
# Epoch 20/50
# 340/340 [==============================] - 409s 1s/step - loss: 0.0206 - dice_coef: 0.9794 - mean_io_u: 0.3449 - auc: 0.9826 - recall: 0.9780 - precision: 0.9832 - val_loss: 0.0336 - val_dice_coef: 0.9659 - val_mean_io_u: 0.3489 - val_auc: 0.9670 - val_recall: 0.9646 - val_precision: 0.9714
#
# Epoch 00020: val_loss improved from 0.03370 to 0.03359, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.20.0.03.hdf5
# Epoch 21/50
# 340/340 [==============================] - 408s 1s/step - loss: 0.0204 - dice_coef: 0.9796 - mean_io_u: 0.3449 - auc: 0.9826 - recall: 0.9782 - precision: 0.9833 - val_loss: 0.0335 - val_dice_coef: 0.9660 - val_mean_io_u: 0.3489 - val_auc: 0.9670 - val_recall: 0.9647 - val_precision: 0.9714
#
# Epoch 00021: val_loss improved from 0.03359 to 0.03348, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.21.0.03.hdf5
# Epoch 22/50
# 340/340 [==============================] - 411s 1s/step - loss: 0.0202 - dice_coef: 0.9798 - mean_io_u: 0.3450 - auc: 0.9826 - recall: 0.9783 - precision: 0.9835 - val_loss: 0.0334 - val_dice_coef: 0.9661 - val_mean_io_u: 0.3490 - val_auc: 0.9669 - val_recall: 0.9646 - val_precision: 0.9717
#
# Epoch 00022: val_loss improved from 0.03348 to 0.03338, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.22.0.03.hdf5
# Epoch 23/50
# 340/340 [==============================] - 409s 1s/step - loss: 0.0201 - dice_coef: 0.9799 - mean_io_u: 0.3450 - auc: 0.9826 - recall: 0.9784 - precision: 0.9836 - val_loss: 0.0333 - val_dice_coef: 0.9662 - val_mean_io_u: 0.3490 - val_auc: 0.9668 - val_recall: 0.9646 - val_precision: 0.9717
#
# Epoch 00023: val_loss improved from 0.03338 to 0.03332, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.23.0.03.hdf5
# Epoch 24/50
# 340/340 [==============================] - 409s 1s/step - loss: 0.0199 - dice_coef: 0.9801 - mean_io_u: 0.3451 - auc: 0.9826 - recall: 0.9785 - precision: 0.9837 - val_loss: 0.0333 - val_dice_coef: 0.9662 - val_mean_io_u: 0.3490 - val_auc: 0.9666 - val_recall: 0.9647 - val_precision: 0.9716
#
# Epoch 00024: val_loss improved from 0.03332 to 0.03329, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.24.0.03.hdf5
# Epoch 25/50
# 340/340 [==============================] - 409s 1s/step - loss: 0.0198 - dice_coef: 0.9802 - mean_io_u: 0.3452 - auc: 0.9826 - recall: 0.9786 - precision: 0.9838 - val_loss: 0.0333 - val_dice_coef: 0.9663 - val_mean_io_u: 0.3491 - val_auc: 0.9664 - val_recall: 0.9646 - val_precision: 0.9717
#
# Epoch 00025: val_loss improved from 0.03329 to 0.03326, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.25.0.03.hdf5
# Epoch 26/50
# 340/340 [==============================] - 410s 1s/step - loss: 0.0196 - dice_coef: 0.9804 - mean_io_u: 0.3453 - auc: 0.9826 - recall: 0.9787 - precision: 0.9839 - val_loss: 0.0332 - val_dice_coef: 0.9663 - val_mean_io_u: 0.3492 - val_auc: 0.9663 - val_recall: 0.9646 - val_precision: 0.9717
#
# Epoch 00026: val_loss improved from 0.03326 to 0.03323, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.26.0.03.hdf5
# Epoch 27/50
# 340/340 [==============================] - 409s 1s/step - loss: 0.0196 - dice_coef: 0.9804 - mean_io_u: 0.3453 - auc: 0.9828 - recall: 0.9788 - precision: 0.9839 - val_loss: 0.0328 - val_dice_coef: 0.9667 - val_mean_io_u: 0.3493 - val_auc: 0.9665 - val_recall: 0.9657 - val_precision: 0.9715
#
# Epoch 00027: val_loss improved from 0.03323 to 0.03282, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.27.0.03.hdf5
# Epoch 28/50
# 340/340 [==============================] - 409s 1s/step - loss: 0.0195 - dice_coef: 0.9805 - mean_io_u: 0.3453 - auc: 0.9828 - recall: 0.9788 - precision: 0.9840 - val_loss: 0.0328 - val_dice_coef: 0.9667 - val_mean_io_u: 0.3493 - val_auc: 0.9665 - val_recall: 0.9656 - val_precision: 0.9716
#
# Epoch 00028: val_loss improved from 0.03282 to 0.03281, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.28.0.03.hdf5
# Epoch 29/50
# 340/340 [==============================] - 412s 1s/step - loss: 0.0195 - dice_coef: 0.9805 - mean_io_u: 0.3454 - auc: 0.9828 - recall: 0.9788 - precision: 0.9840 - val_loss: 0.0328 - val_dice_coef: 0.9667 - val_mean_io_u: 0.3493 - val_auc: 0.9665 - val_recall: 0.9656 - val_precision: 0.9716
#
# Epoch 00029: val_loss improved from 0.03281 to 0.03281, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.29.0.03.hdf5
# Epoch 30/50
# 340/340 [==============================] - 410s 1s/step - loss: 0.0195 - dice_coef: 0.9805 - mean_io_u: 0.3454 - auc: 0.9828 - recall: 0.9789 - precision: 0.9841 - val_loss: 0.0328 - val_dice_coef: 0.9667 - val_mean_io_u: 0.3493 - val_auc: 0.9665 - val_recall: 0.9656 - val_precision: 0.9716
#
# Epoch 00030: val_loss did not improve from 0.03281
# Epoch 31/50
# 340/340 [==============================] - 409s 1s/step - loss: 0.0194 - dice_coef: 0.9806 - mean_io_u: 0.3454 - auc: 0.9827 - recall: 0.9794 - precision: 0.9836 - val_loss: 0.0328 - val_dice_coef: 0.9667 - val_mean_io_u: 0.3493 - val_auc: 0.9668 - val_recall: 0.9651 - val_precision: 0.9722
#
# Epoch 00031: val_loss improved from 0.03281 to 0.03277, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.31.0.03.hdf5
# Epoch 32/50
# 340/340 [==============================] - 409s 1s/step - loss: 0.0194 - dice_coef: 0.9806 - mean_io_u: 0.3454 - auc: 0.9828 - recall: 0.9791 - precision: 0.9839 - val_loss: 0.0328 - val_dice_coef: 0.9668 - val_mean_io_u: 0.3493 - val_auc: 0.9668 - val_recall: 0.9649 - val_precision: 0.9724
#
# Epoch 00032: val_loss improved from 0.03277 to 0.03276, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.32.0.03.hdf5
# Epoch 33/50
# 340/340 [==============================] - 409s 1s/step - loss: 0.0194 - dice_coef: 0.9806 - mean_io_u: 0.3454 - auc: 0.9828 - recall: 0.9790 - precision: 0.9840 - val_loss: 0.0328 - val_dice_coef: 0.9668 - val_mean_io_u: 0.3493 - val_auc: 0.9669 - val_recall: 0.9648 - val_precision: 0.9724
#
# Epoch 00033: val_loss improved from 0.03276 to 0.03276, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.33.0.03.hdf5
# Epoch 34/50
# 340/340 [==============================] - 410s 1s/step - loss: 0.0194 - dice_coef: 0.9806 - mean_io_u: 0.3454 - auc: 0.9828 - recall: 0.9790 - precision: 0.9840 - val_loss: 0.0328 - val_dice_coef: 0.9668 - val_mean_io_u: 0.3493 - val_auc: 0.9669 - val_recall: 0.9648 - val_precision: 0.9724
#
# Epoch 00034: val_loss improved from 0.03276 to 0.03276, saving model to ../../output/checkpoints/mobilenetv2/unet_weights.34.0.03.hdf5
# Epoch 35/50
# 340/340 [==============================] - 411s 1s/step - loss: 0.0194 - dice_coef: 0.9806 - mean_io_u: 0.3454 - auc: 0.9828 - recall: 0.9790 - precision: 0.9840 - val_loss: 0.0328 - val_dice_coef: 0.9668 - val_mean_io_u: 0.3493 - val_auc: 0.9669 - val_recall: 0.9648 - val_precision: 0.9724
#
# Epoch 00035: val_loss did not improve from 0.03276
# Epoch 36/50
# 340/340 [==============================] - 410s 1s/step - loss: 0.0194 - dice_coef: 0.9806 - mean_io_u: 0.3454 - auc: 0.9829 - recall: 0.9790 - precision: 0.9840 - val_loss: 0.0328 - val_dice_coef: 0.9668 - val_mean_io_u: 0.3493 - val_auc: 0.9669 - val_recall: 0.9648 - val_precision: 0.9724
#
# Epoch 00036: val_loss did not improve from 0.03276
# Epoch 37/50
# 340/340 [==============================] - 410s 1s/step - loss: 0.0194 - dice_coef: 0.9806 - mean_io_u: 0.3454 - auc: 0.9829 - recall: 0.9790 - precision: 0.9840 - val_loss: 0.0328 - val_dice_coef: 0.9668 - val_mean_io_u: 0.3493 - val_auc: 0.9669 - val_recall: 0.9648 - val_precision: 0.9724
#
# Epoch 00037: val_loss did not improve from 0.03276
# Epoch 38/50
# 340/340 [==============================] - 410s 1s/step - loss: 0.0194 - dice_coef: 0.9806 - mean_io_u: 0.3454 - auc: 0.9829 - recall: 0.9790 - precision: 0.9840 - val_loss: 0.0328 - val_dice_coef: 0.9668 - val_mean_io_u: 0.3493 - val_auc: 0.9669 - val_recall: 0.9648 - val_precision: 0.9724
#
# Epoch 00038: val_loss did not improve from 0.03276
# Epoch 39/50
# 340/340 [==============================] - 410s 1s/step - loss: 0.0194 - dice_coef: 0.9806 - mean_io_u: 0.3454 - auc: 0.9829 - recall: 0.9790 - precision: 0.9840 - val_loss: 0.0328 - val_dice_coef: 0.9668 - val_mean_io_u: 0.3493 - val_auc: 0.9669 - val_recall: 0.9648 - val_precision: 0.9724
# Epoch 00039: val_loss did not improve from 0.03276
# Epoch 40/50
# 340/340 [==============================] - 410s 1s/step - loss: 0.0194 - dice_coef: 0.9806 - mean_io_u: 0.3454 - auc: 0.9829 - recall: 0.9790 - precision: 0.9840 - val_loss: 0.0328 - val_dice_coef: 0.9668 - val_mean_io_u: 0.3493 - val_auc: 0.9669 - val_recall: 0.9648 - val_precision: 0.9724
#
# Epoch 00040: val_loss did not improve from 0.03276
# Epoch 41/50
# 340/340 [==============================] - 411s 1s/step - loss: 0.0194 - dice_coef: 0.9806 - mean_io_u: 0.3454 - auc: 0.9829 - recall: 0.9790 - precision: 0.9840 - val_loss: 0.0328 - val_dice_coef: 0.9668 - val_mean_io_u: 0.3493 - val_auc: 0.9669 - val_recall: 0.9648 - val_precision: 0.9724
#
# Epoch 00041: val_loss did not improve from 0.03276
# Epoch 42/50
# 340/340 [==============================] - 409s 1s/step - loss: 0.0194 - dice_coef: 0.9806 - mean_io_u: 0.3454 - auc: 0.9829 - recall: 0.9790 - precision: 0.9840 - val_loss: 0.0328 - val_dice_coef: 0.9668 - val_mean_io_u: 0.3493 - val_auc: 0.9669 - val_recall: 0.9648 - val_precision: 0.9724
#
# Epoch 00042: val_loss did not improve from 0.03276
# Epoch 43/50
# 340/340 [==============================] - 410s 1s/step - loss: 0.0194 - dice_coef: 0.9806 - mean_io_u: 0.3454 - auc: 0.9829 - recall: 0.9790 - precision: 0.9840 - val_loss: 0.0328 - val_dice_coef: 0.9668 - val_mean_io_u: 0.3493 - val_auc: 0.9669 - val_recall: 0.9648 - val_precision: 0.9724
#
# Epoch 00043: val_loss did not improve from 0.03276
# Epoch 44/50
# 340/340 [==============================] - 410s 1s/step - loss: 0.0194 - dice_coef: 0.9806 - mean_io_u: 0.3454 - auc: 0.9829 - recall: 0.9790 - precision: 0.9840 - val_loss: 0.0328 - val_dice_coef: 0.9668 - val_mean_io_u: 0.3493 - val_auc: 0.9669 - val_recall: 0.9648 - val_precision: 0.9724
#
# Epoch 00044: val_loss did not improve from 0.03276

# %%
test_x, test_y= load_data(path='../../dataset/LSP/test/',mode='testing')
test_dataset = tf_dataset(test_x, test_y, batch=BATCH)

print("test data: ", len(test_x))
test_steps = (len(test_x)//BATCH)
if len(test_x) % BATCH != 0:
    test_steps += 1
# Out:
# test data:  138

# %%
model.load_weights('../../output/checkpoints/mobilenetv2/unet_weights.34.0.03.hdf5')
model.evaluate(test_dataset)
# Out:
# 35/35 [==============================] - 33s 911ms/step - loss: 0.0421 - dice_coef: 0.9580 - mean_io_u: 0.3726 - auc: 0.9616 - recall: 0.9382 - precision: 0.9792
# [0.04213186353445053,
#  0.9579896330833435,
#  0.3725845217704773,
#  0.9615508913993835,
#  0.9381855130195618,
#  0.9792360663414001]

# %%
def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = np.expand_dims(x, axis=-1)
    x = x/255.0
    return x

# %%
def mask_parse(mask):
    mask = np.squeeze(mask)
    mask = [mask, mask, mask]
    mask = np.transpose(mask, (1, 2, 0))
    return mask

# %%
for i, (x, y) in enumerate(zip(test_x[:10], test_y[:10])):
    x = read_image(x)
    y = read_mask(y)
    y_pred = model.predict(np.expand_dims(x, axis=0))[0] > 0.5
    h, w, _ = x.shape
    white_line = np.ones((h, 10, 3))

    all_images = [
        x, white_line,
        mask_parse(y), white_line,
        mask_parse(y_pred)
    ]
    image = np.concatenate(all_images, axis=1)
    
    fig = plt.figure(figsize=(12, 12))
    a = fig.add_subplot(1, 1, 1)
    imgplot = plt.imshow(image)
