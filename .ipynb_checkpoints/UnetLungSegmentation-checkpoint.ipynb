# %% [markdown]
# # Lung Segmentation

# %% [markdown]
# ## import all packages

# %%
import os
import datetime
import time
import numpy as np
import cv2
from glob import glob
import matplotlib.pyplot as plt

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv2D, Activation, BatchNormalization,MaxPooling2D,Dense,concatenate
from tensorflow.keras.layers import UpSampling2D, Input, Concatenate,Conv2DTranspose
from tensorflow.keras.layers import Input,UpSampling3D,Dense, Dropout,BatchNormalization, Activation
from tensorflow.keras.layers import GlobalAveragePooling2D, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint,LearningRateScheduler
from tensorflow.keras.metrics import Recall, Precision,MeanIoU,AUC
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
# Out:
# /Users/user/miniforge3/envs/Apple/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
IMAGE_SIZE = 256
EPOCHS = 50
BATCH = 4
LR = 1e-4

PATH = './dataset/newdataset/'

# %% [markdown]
# # Load dataset

# %%
def load_data(path='../dataset/newdataset/', split=0.1,mode=''):
    images = sorted(glob(os.path.join(path, "images/*")))
    masks = sorted(glob(os.path.join(path, "masks/*")))
    
    if mode == 'training':
        total_size = len(images)
        valid_size = int(split * total_size)
        train_x, valid_x = train_test_split(images, test_size=valid_size, random_state=42)
        train_y, valid_y = train_test_split(masks, test_size=valid_size, random_state=42)

        return (train_x, train_y), (valid_x, valid_y)
    
    if mode == 'testing':
        return (images,masks)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (256, 256))
    x = x/255.0
    x = np.expand_dims(x, axis=-1)
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
    x.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    y.set_shape([256, 256, 1])
    return x, y

def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
#     dataset = dataset.repeat()
    return dataset

# %%
(train_x, train_y), (valid_x, valid_y) = load_data(PATH,mode='training')

print("Training data: ", len(train_x))
print("Validation data: ", len(valid_x))
# Out:
# Training data:  900
# Validation data:  100

# %%
def read_and_rgb(x):
    x = cv2.imread(x)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    return x

# %%
fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(valid_x[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(valid_x[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(valid_x[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(valid_x[3]))
imgplot.set_clim(0.0, 2.1)

fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(valid_y[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(valid_y[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(valid_y[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(valid_y[3]))
imgplot.set_clim(0.0, 1.4)

# %% [markdown]
# ## load pretrained model from tensorflow

# %%
def build_model(inputs):
    mobilenetv2 = tf.keras.applications.MobileNetV2(
        input_tensor = inputs, 
        weights="imagenet", include_top=False, alpha=0.35)
    mobilenetv2.trainable = False
    x = mobilenetv2.get_layer('out_relu').output
    x = Conv2D(128,3,name='final_conv',padding='same',activation='relu')(x)
    x = GlobalAveragePooling2D(name='gap')(x)
    output = Dense(2,activation='sigmoid')(x)
    return tf.keras.Model(inputs,output)

# %% [markdown]
# # build unet from the pretrained model
#
# https://github.com/nikhilroxtomar/Unet-with-Pretrained-Encoder/blob/master/U-Net_with_Pretrained_MobileNetV2_as_Encoder.ipynb
#
# ![image](https://github.com/nikhilroxtomar/Unet-with-Pretrained-Encoder/raw/5898a1e1ee66df875239d679839a30e419b20375//images/u-net-architecture.png)

# %%
def model():
    inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")
    
    encoder = build_model(inputs)
#     encoder.load_weights('../../output/checkpoints/mobilenetv2/512_128weights.16-0.31.hdf5')
    skip_connection_names = ["input_image","block_1_expand_relu", "block_3_expand_relu", "block_6_expand_relu"]
    encoder_output = encoder.get_layer("block_13_expand_relu").output
    f = [ 16, 32, 48, 64]
    x = encoder_output
    for i in range(1, len(skip_connection_names)+1, 1):
        x_skip = encoder.get_layer(skip_connection_names[-i]).output
        x =  Conv2DTranspose(filters=f[-i],kernel_size=3,strides=2,padding='same')(x)
        x = Concatenate()([x, x_skip])
        
        x = Conv2D(f[-i], (5, 5), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        
        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        
    x = Conv2D(1, (1, 1), padding="same")(x)
    x = Activation("sigmoid")(x)
    
    model = Model(inputs, x)
    
    return model

# %%
# def unet_plus_plus():
#     return

# %%
model = model()
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Metal device set to: Apple M1
# 2022-09-06 16:19:13.243176: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-09-06 16:19:13.243268: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 128, 128, 16) 432         input_image[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 128, 128, 16) 64          Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 128, 128, 16) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 128, 128, 16) 144         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 128, 128, 16) 64          expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 128, 128, 16) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 128, 128, 8)  128         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 128, 128, 8)  32          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 128, 128, 48) 384         expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 128, 128, 48) 192         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 128, 128, 48) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 129, 129, 48) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 64, 64, 48)   432         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 64, 64, 48)   192         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 64, 64, 48)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 64, 64, 8)    384         block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 64, 64, 8)    32          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 64, 64, 48)   384         block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 64, 64, 48)   192         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 64, 64, 48)   0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 64, 64, 48)   432         block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 64, 64, 48)   192         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 64, 64, 48)   0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 64, 64, 8)    384         block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 64, 64, 8)    32          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 64, 64, 8)    0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 64, 64, 48)   384         block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 64, 64, 48)   192         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 64, 64, 48)   0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 65, 65, 48)   0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 32, 32, 48)   432         block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 32, 32, 48)   192         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 32, 32, 48)   0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 32, 32, 16)   768         block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 32, 32, 16)   64          block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 32, 32, 96)   1536        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 32, 32, 96)   384         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 32, 32, 96)   0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 32, 32, 96)   864         block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 32, 32, 96)   384         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 32, 32, 96)   0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 32, 32, 16)   1536        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 32, 32, 16)   64          block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 32, 32, 16)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 32, 32, 96)   1536        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 32, 32, 96)   384         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 32, 32, 96)   0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 32, 32, 96)   864         block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 32, 32, 96)   384         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 32, 32, 96)   0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 32, 32, 16)   1536        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 32, 32, 16)   64          block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 32, 32, 16)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 32, 32, 96)   1536        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 32, 32, 96)   384         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 32, 32, 96)   0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 33, 33, 96)   0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 16, 16, 96)   864         block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 16, 16, 96)   384         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 16, 16, 96)   0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 16, 16, 24)   2304        block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 16, 16, 24)   96          block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 16, 16, 144)  3456        block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 16, 16, 144)  576         block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 16, 16, 144)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 16, 16, 144)  1296        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 16, 16, 144)  576         block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 16, 16, 144)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 16, 16, 24)   3456        block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 16, 16, 24)   96          block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 16, 16, 24)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 16, 16, 144)  3456        block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 16, 16, 144)  576         block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 16, 16, 144)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 16, 16, 144)  1296        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 16, 16, 144)  576         block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 16, 16, 144)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 16, 16, 24)   3456        block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 16, 16, 24)   96          block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 16, 16, 24)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 16, 16, 144)  3456        block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 16, 16, 144)  576         block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 16, 16, 144)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 16, 16, 144)  1296        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 16, 16, 144)  576         block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 16, 16, 144)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 16, 16, 24)   3456        block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 16, 16, 24)   96          block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 16, 16, 24)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 16, 16, 144)  3456        block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 16, 16, 144)  576         block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 16, 16, 144)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 16, 16, 144)  1296        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 16, 16, 144)  576         block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 16, 16, 144)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 16, 16, 32)   4608        block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 16, 16, 32)   128         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 16, 16, 192)  6144        block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 16, 16, 192)  768         block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 16, 16, 192)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 16, 16, 192)  1728        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 16, 16, 192)  768         block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 16, 16, 192)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 16, 16, 32)   6144        block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 16, 16, 32)   128         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 16, 16, 32)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 16, 16, 192)  6144        block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 16, 16, 192)  768         block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 16, 16, 192)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 16, 16, 192)  1728        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 16, 16, 192)  768         block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 16, 16, 192)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 16, 16, 32)   6144        block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 16, 16, 32)   128         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 16, 16, 32)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 16, 16, 192)  6144        block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 16, 16, 192)  768         block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 16, 16, 192)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 64)   110656      block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 160)  0           conv2d_transpose[0][0]
#                                                                  block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   92224       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   102464      activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 48)   27696       activation_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 96)   0           conv2d_transpose_1[0][0]
#                                                                  block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 48)   41520       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 48)   192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 48)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 48)   57648       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 48)   192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 48)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 32) 13856       activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 80) 0           conv2d_transpose_2[0][0]
#                                                                  block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 32) 23072       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 32) 128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128, 128, 32) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 32) 25632       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 32) 128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 32) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 16) 4624        activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 19) 0           conv2d_transpose_3[0][0]
#                                                                  input_image[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 256, 16) 2752        concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 256, 256, 16) 64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 256, 256, 16) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 16) 6416        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 256, 256, 16) 64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 256, 256, 16) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 1)  17          activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256, 256, 1)  0           conv2d_8[0][0]
# ==================================================================================================
# Total params: 608,369
# Trainable params: 509,217
# Non-trainable params: 99,152
# __________________________________________________________________________________________________

# %% [markdown]
# ## Define Evaluatoin Metrics

# %%
smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def jackard_index(y_true, y_pred):
    
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) -intersection + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)
def jackard_index_loss(y_true, y_pred):
    return 1.0 - jackard_index(y_true, y_pred)

# %%
train_dataset = tf_dataset(train_x, train_y, batch=BATCH)
valid_dataset = tf_dataset(valid_x, valid_y, batch=BATCH)

# %%
opt = tf.keras.optimizers.Nadam(LR)
metrics = [dice_coef, jackard_index, AUC(curve='PR'), Recall(), Precision()]
# model.load_weights('./output/unet_weights.19.0.03.hdf5')
model.compile(loss = jackard_index_loss, optimizer=opt, metrics=metrics)

# %%
log_dir = "logs/unet/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3),
    tf.keras.callbacks.TensorBoard(log_dir=log_dir),
    ModelCheckpoint(
        './output/unet_weights.{epoch:02d}.{val_loss:.2f}.hdf5',
        monitor='val_loss',save_best_only=True,save_weights_only=True,verbose=1),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False)
]
# Out:
# 2022-09-06 16:19:14.008614: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session initializing.
# 2022-09-06 16:19:14.008621: I tensorflow/core/profiler/lib/profiler_session.cc:141] Profiler session started.
# 2022-09-06 16:19:14.008819: I tensorflow/core/profiler/lib/profiler_session.cc:159] Profiler session tear down.

# %%
train_steps = len(train_x)//BATCH
valid_steps = len(valid_x)//BATCH

if len(train_x) % BATCH != 0:
    train_steps += 1
if len(valid_x) % BATCH != 0:
    valid_steps += 1

model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=40,
    steps_per_epoch=train_steps,
    validation_steps=valid_steps,
    callbacks=callbacks
)
# Out:
# /Users/user/miniforge3/envs/Apple/lib/python3.9/site-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# 2022-09-06 16:19:14.265552: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-09-06 16:19:14.265658: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/40
# 2022-09-06 16:19:15.524887: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
#   1/225 [..............................] - ETA: 8:18 - loss: 0.7715 - dice_coef: 0.3721 - jackard_index: 0.2285 - auc: 0.2987 - recall: 0.6045 - precision: 0.2738
# 2022-09-06 16:19:16.560072: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session initializing.
# 2022-09-06 16:19:16.560086: I tensorflow/core/profiler/lib/profiler_session.cc:141] Profiler session started.
#   2/225 [..............................] - ETA: 1:04 - loss: 0.7724 - dice_coef: 0.3708 - jackard_index: 0.2276 - auc: 0.3026 - recall: 0.6128 - precision: 0.2749
# 2022-09-06 16:19:16.785460: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-09-06 16:19:16.786575: I tensorflow/core/profiler/lib/profiler_session.cc:159] Profiler session tear down.
# 2022-09-06 16:19:16.787951: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs/unet/20220906-161914/train/plugins/profile/2022_09_06_16_19_16
# 2022-09-06 16:19:16.789132: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for trace.json.gz to logs/unet/20220906-161914/train/plugins/profile/2022_09_06_16_19_16/users-MacBook-Pro.local.trace.json.gz
# 2022-09-06 16:19:16.790441: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs/unet/20220906-161914/train/plugins/profile/2022_09_06_16_19_16
# 2022-09-06 16:19:16.790590: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for memory_profile.json.gz to logs/unet/20220906-161914/train/plugins/profile/2022_09_06_16_19_16/users-MacBook-Pro.local.memory_profile.json.gz
# 2022-09-06 16:19:16.790979: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: logs/unet/20220906-161914/train/plugins/profile/2022_09_06_16_19_16Dumped tool data for xplane.pb to logs/unet/20220906-161914/train/plugins/profile/2022_09_06_16_19_16/users-MacBook-Pro.local.xplane.pb
# Dumped tool data for overview_page.pb to logs/unet/20220906-161914/train/plugins/profile/2022_09_06_16_19_16/users-MacBook-Pro.local.overview_page.pb
# Dumped tool data for input_pipeline.pb to logs/unet/20220906-161914/train/plugins/profile/2022_09_06_16_19_16/users-MacBook-Pro.local.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to logs/unet/20220906-161914/train/plugins/profile/2022_09_06_16_19_16/users-MacBook-Pro.local.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to logs/unet/20220906-161914/train/plugins/profile/2022_09_06_16_19_16/users-MacBook-Pro.local.kernel_stats.pb
# 225/225 [==============================] - ETA: 0s - loss: 0.3828 - dice_coef: 0.7535 - jackard_index: 0.6172 - auc: 0.9742 - recall: 0.9686 - precision: 0.7887
# 2022-09-06 16:20:03.256787: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 225/225 [==============================] - 52s 224ms/step - loss: 0.3828 - dice_coef: 0.7535 - jackard_index: 0.6172 - auc: 0.9742 - recall: 0.9686 - precision: 0.7887 - val_loss: 0.3375 - val_dice_coef: 0.7968 - val_jackard_index: 0.6625 - val_auc: 0.9950 - val_recall: 0.9886 - val_precision: 0.9307
#
# Epoch 00001: val_loss improved from inf to 0.33746, saving model to ./output/unet_weights.01.0.34.hdf5
# Epoch 2/40
# 225/225 [==============================] - 50s 223ms/step - loss: 0.2588 - dice_coef: 0.8508 - jackard_index: 0.7412 - auc: 0.9945 - recall: 0.9836 - precision: 0.9543 - val_loss: 0.2342 - val_dice_coef: 0.8673 - val_jackard_index: 0.7658 - val_auc: 0.9956 - val_recall: 0.9722 - val_precision: 0.9777
#
# Epoch 00002: val_loss improved from 0.33746 to 0.23417, saving model to ./output/unet_weights.02.0.23.hdf5
# Epoch 3/40
# 225/225 [==============================] - 49s 219ms/step - loss: 0.2177 - dice_coef: 0.8775 - jackard_index: 0.7823 - auc: 0.9947 - recall: 0.9823 - precision: 0.9657 - val_loss: 0.1982 - val_dice_coef: 0.8899 - val_jackard_index: 0.8018 - val_auc: 0.9954 - val_recall: 0.9714 - val_precision: 0.9809
#
# Epoch 00003: val_loss improved from 0.23417 to 0.19816, saving model to ./output/unet_weights.03.0.20.hdf5
# Epoch 4/40
# 225/225 [==============================] - 50s 220ms/step - loss: 0.1847 - dice_coef: 0.8980 - jackard_index: 0.8153 - auc: 0.9946 - recall: 0.9811 - precision: 0.9717 - val_loss: 0.1710 - val_dice_coef: 0.9064 - val_jackard_index: 0.8290 - val_auc: 0.9952 - val_recall: 0.9732 - val_precision: 0.9810
#
# Epoch 00004: val_loss improved from 0.19816 to 0.17102, saving model to ./output/unet_weights.04.0.17.hdf5
# Epoch 5/40
# 225/225 [==============================] - 51s 225ms/step - loss: 0.1576 - dice_coef: 0.9143 - jackard_index: 0.8424 - auc: 0.9944 - recall: 0.9801 - precision: 0.9755 - val_loss: 0.1481 - val_dice_coef: 0.9200 - val_jackard_index: 0.8519 - val_auc: 0.9949 - val_recall: 0.9727 - val_precision: 0.9823
#
# Epoch 00005: val_loss improved from 0.17102 to 0.14809, saving model to ./output/unet_weights.05.0.15.hdf5
# Epoch 6/40
# 225/225 [==============================] - 50s 220ms/step - loss: 0.1354 - dice_coef: 0.9272 - jackard_index: 0.8646 - auc: 0.9942 - recall: 0.9794 - precision: 0.9781 - val_loss: 0.1285 - val_dice_coef: 0.9313 - val_jackard_index: 0.8715 - val_auc: 0.9945 - val_recall: 0.9724 - val_precision: 0.9831
#
# Epoch 00006: val_loss improved from 0.14809 to 0.12848, saving model to ./output/unet_weights.06.0.13.hdf5
# Epoch 7/40
# 225/225 [==============================] - 50s 221ms/step - loss: 0.1175 - dice_coef: 0.9375 - jackard_index: 0.8825 - auc: 0.9939 - recall: 0.9788 - precision: 0.9799 - val_loss: 0.1132 - val_dice_coef: 0.9400 - val_jackard_index: 0.8868 - val_auc: 0.9939 - val_recall: 0.9714 - val_precision: 0.9835
#
# Epoch 00007: val_loss improved from 0.12848 to 0.11320, saving model to ./output/unet_weights.07.0.11.hdf5
# Epoch 8/40
# 225/225 [==============================] - 51s 226ms/step - loss: 0.1030 - dice_coef: 0.9456 - jackard_index: 0.8970 - auc: 0.9936 - recall: 0.9786 - precision: 0.9813 - val_loss: 0.1004 - val_dice_coef: 0.9471 - val_jackard_index: 0.8996 - val_auc: 0.9932 - val_recall: 0.9719 - val_precision: 0.9834
#
# Epoch 00008: val_loss improved from 0.11320 to 0.10036, saving model to ./output/unet_weights.08.0.10.hdf5
# Epoch 9/40
# 225/225 [==============================] - 50s 224ms/step - loss: 0.0913 - dice_coef: 0.9521 - jackard_index: 0.9087 - auc: 0.9933 - recall: 0.9784 - precision: 0.9824 - val_loss: 0.0905 - val_dice_coef: 0.9526 - val_jackard_index: 0.9095 - val_auc: 0.9924 - val_recall: 0.9719 - val_precision: 0.9831
#
# Epoch 00009: val_loss improved from 0.10036 to 0.09054, saving model to ./output/unet_weights.09.0.09.hdf5
# Epoch 10/40
# 225/225 [==============================] - 50s 223ms/step - loss: 0.0818 - dice_coef: 0.9573 - jackard_index: 0.9182 - auc: 0.9930 - recall: 0.9784 - precision: 0.9833 - val_loss: 0.0816 - val_dice_coef: 0.9575 - val_jackard_index: 0.9184 - val_auc: 0.9906 - val_recall: 0.9767 - val_precision: 0.9798
#
# Epoch 00010: val_loss improved from 0.09054 to 0.08157, saving model to ./output/unet_weights.10.0.08.hdf5
# Epoch 11/40
# 225/225 [==============================] - 50s 222ms/step - loss: 0.0739 - dice_coef: 0.9616 - jackard_index: 0.9261 - auc: 0.9927 - recall: 0.9785 - precision: 0.9840 - val_loss: 0.0769 - val_dice_coef: 0.9600 - val_jackard_index: 0.9231 - val_auc: 0.9909 - val_recall: 0.9708 - val_precision: 0.9834
#
# Epoch 00011: val_loss improved from 0.08157 to 0.07687, saving model to ./output/unet_weights.11.0.08.hdf5
# Epoch 12/40
# 225/225 [==============================] - 50s 221ms/step - loss: 0.0675 - dice_coef: 0.9651 - jackard_index: 0.9325 - auc: 0.9924 - recall: 0.9786 - precision: 0.9846 - val_loss: 0.0701 - val_dice_coef: 0.9637 - val_jackard_index: 0.9299 - val_auc: 0.9890 - val_recall: 0.9749 - val_precision: 0.9810
#
# Epoch 00012: val_loss improved from 0.07687 to 0.07007, saving model to ./output/unet_weights.12.0.07.hdf5
# Epoch 13/40
# 225/225 [==============================] - 50s 221ms/step - loss: 0.0623 - dice_coef: 0.9678 - jackard_index: 0.9377 - auc: 0.9921 - recall: 0.9786 - precision: 0.9850 - val_loss: 0.0670 - val_dice_coef: 0.9653 - val_jackard_index: 0.9330 - val_auc: 0.9892 - val_recall: 0.9739 - val_precision: 0.9814
#
# Epoch 00013: val_loss improved from 0.07007 to 0.06702, saving model to ./output/unet_weights.13.0.07.hdf5
# Epoch 14/40
# 225/225 [==============================] - 50s 222ms/step - loss: 0.0573 - dice_coef: 0.9705 - jackard_index: 0.9427 - auc: 0.9921 - recall: 0.9789 - precision: 0.9858 - val_loss: 0.0653 - val_dice_coef: 0.9662 - val_jackard_index: 0.9347 - val_auc: 0.9894 - val_recall: 0.9664 - val_precision: 0.9860
#
# Epoch 00014: val_loss improved from 0.06702 to 0.06532, saving model to ./output/unet_weights.14.0.07.hdf5
# Epoch 15/40
# 225/225 [==============================] - 50s 221ms/step - loss: 0.0533 - dice_coef: 0.9726 - jackard_index: 0.9467 - auc: 0.9919 - recall: 0.9793 - precision: 0.9863 - val_loss: 0.0615 - val_dice_coef: 0.9682 - val_jackard_index: 0.9385 - val_auc: 0.9845 - val_recall: 0.9792 - val_precision: 0.9761
#
# Epoch 00015: val_loss improved from 0.06532 to 0.06153, saving model to ./output/unet_weights.15.0.06.hdf5
# Epoch 16/40
# 225/225 [==============================] - 49s 218ms/step - loss: 0.0498 - dice_coef: 0.9745 - jackard_index: 0.9502 - auc: 0.9916 - recall: 0.9796 - precision: 0.9867 - val_loss: 0.0586 - val_dice_coef: 0.9698 - val_jackard_index: 0.9414 - val_auc: 0.9856 - val_recall: 0.9724 - val_precision: 0.9824
#
# Epoch 00016: val_loss improved from 0.06153 to 0.05857, saving model to ./output/unet_weights.16.0.06.hdf5
# Epoch 17/40
# 225/225 [==============================] - 49s 219ms/step - loss: 0.0469 - dice_coef: 0.9760 - jackard_index: 0.9531 - auc: 0.9915 - recall: 0.9798 - precision: 0.9872 - val_loss: 0.0587 - val_dice_coef: 0.9697 - val_jackard_index: 0.9413 - val_auc: 0.9872 - val_recall: 0.9683 - val_precision: 0.9838
#
# Epoch 00017: val_loss did not improve from 0.05857
# Epoch 18/40
# 225/225 [==============================] - 50s 220ms/step - loss: 0.0443 - dice_coef: 0.9773 - jackard_index: 0.9557 - auc: 0.9917 - recall: 0.9802 - precision: 0.9876 - val_loss: 0.0557 - val_dice_coef: 0.9713 - val_jackard_index: 0.9443 - val_auc: 0.9856 - val_recall: 0.9730 - val_precision: 0.9812
#
# Epoch 00018: val_loss improved from 0.05857 to 0.05570, saving model to ./output/unet_weights.18.0.06.hdf5
# Epoch 19/40
# 225/225 [==============================] - 52s 232ms/step - loss: 0.0419 - dice_coef: 0.9786 - jackard_index: 0.9581 - auc: 0.9919 - recall: 0.9805 - precision: 0.9880 - val_loss: 0.0547 - val_dice_coef: 0.9719 - val_jackard_index: 0.9453 - val_auc: 0.9842 - val_recall: 0.9730 - val_precision: 0.9808
#
# Epoch 00019: val_loss improved from 0.05570 to 0.05465, saving model to ./output/unet_weights.19.0.05.hdf5
# Epoch 20/40
# 225/225 [==============================] - 51s 227ms/step - loss: 0.0400 - dice_coef: 0.9796 - jackard_index: 0.9600 - auc: 0.9918 - recall: 0.9807 - precision: 0.9883 - val_loss: 0.0547 - val_dice_coef: 0.9719 - val_jackard_index: 0.9453 - val_auc: 0.9809 - val_recall: 0.9770 - val_precision: 0.9761
# Epoch 00020: val_loss improved from 0.05465 to 0.05465, saving model to ./output/unet_weights.20.0.05.hdf5
# Epoch 21/40
# 225/225 [==============================] - 50s 223ms/step - loss: 0.0384 - dice_coef: 0.9804 - jackard_index: 0.9616 - auc: 0.9916 - recall: 0.9809 - precision: 0.9885 - val_loss: 0.0545 - val_dice_coef: 0.9719 - val_jackard_index: 0.9455 - val_auc: 0.9835 - val_recall: 0.9678 - val_precision: 0.9835
#
# Epoch 00021: val_loss improved from 0.05465 to 0.05452, saving model to ./output/unet_weights.21.0.05.hdf5
# Epoch 22/40
# 225/225 [==============================] - 51s 225ms/step - loss: 0.0366 - dice_coef: 0.9814 - jackard_index: 0.9634 - auc: 0.9916 - recall: 0.9812 - precision: 0.9890 - val_loss: 0.0523 - val_dice_coef: 0.9731 - val_jackard_index: 0.9477 - val_auc: 0.9810 - val_recall: 0.9746 - val_precision: 0.9789
#
# Epoch 00022: val_loss improved from 0.05452 to 0.05229, saving model to ./output/unet_weights.22.0.05.hdf5
# Epoch 23/40
# 225/225 [==============================] - 50s 223ms/step - loss: 0.0349 - dice_coef: 0.9822 - jackard_index: 0.9651 - auc: 0.9915 - recall: 0.9816 - precision: 0.9894 - val_loss: 0.0507 - val_dice_coef: 0.9740 - val_jackard_index: 0.9493 - val_auc: 0.9810 - val_recall: 0.9736 - val_precision: 0.9803
#
# Epoch 00023: val_loss improved from 0.05229 to 0.05067, saving model to ./output/unet_weights.23.0.05.hdf5
# Epoch 24/40
# 225/225 [==============================] - 50s 222ms/step - loss: 0.0337 - dice_coef: 0.9828 - jackard_index: 0.9663 - auc: 0.9914 - recall: 0.9818 - precision: 0.9896 - val_loss: 0.0508 - val_dice_coef: 0.9739 - val_jackard_index: 0.9492 - val_auc: 0.9795 - val_recall: 0.9756 - val_precision: 0.9782
#
# Epoch 00024: val_loss did not improve from 0.05067
# Epoch 25/40
# 225/225 [==============================] - 50s 222ms/step - loss: 0.0324 - dice_coef: 0.9835 - jackard_index: 0.9676 - auc: 0.9913 - recall: 0.9821 - precision: 0.9899 - val_loss: 0.0553 - val_dice_coef: 0.9715 - val_jackard_index: 0.9447 - val_auc: 0.9791 - val_recall: 0.9631 - val_precision: 0.9842
#
# Epoch 00025: val_loss did not improve from 0.05067
# Epoch 26/40
# 225/225 [==============================] - 49s 217ms/step - loss: 0.0316 - dice_coef: 0.9839 - jackard_index: 0.9684 - auc: 0.9911 - recall: 0.9821 - precision: 0.9901 - val_loss: 0.0519 - val_dice_coef: 0.9733 - val_jackard_index: 0.9481 - val_auc: 0.9796 - val_recall: 0.9659 - val_precision: 0.9843
#
# Epoch 00026: val_loss did not improve from 0.05067
# Epoch 27/40
# 225/225 [==============================] - 49s 218ms/step - loss: 0.0306 - dice_coef: 0.9845 - jackard_index: 0.9694 - auc: 0.9915 - recall: 0.9827 - precision: 0.9904 - val_loss: 0.0481 - val_dice_coef: 0.9753 - val_jackard_index: 0.9519 - val_auc: 0.9795 - val_recall: 0.9731 - val_precision: 0.9813
#
# Epoch 00027: val_loss improved from 0.05067 to 0.04815, saving model to ./output/unet_weights.27.0.05.hdf5
# Epoch 28/40
# 225/225 [==============================] - 49s 219ms/step - loss: 0.0299 - dice_coef: 0.9848 - jackard_index: 0.9701 - auc: 0.9917 - recall: 0.9829 - precision: 0.9907 - val_loss: 0.0482 - val_dice_coef: 0.9753 - val_jackard_index: 0.9518 - val_auc: 0.9797 - val_recall: 0.9720 - val_precision: 0.9822
#
# Epoch 00028: val_loss did not improve from 0.04815
# Epoch 29/40
# 225/225 [==============================] - 49s 219ms/step - loss: 0.0295 - dice_coef: 0.9850 - jackard_index: 0.9705 - auc: 0.9918 - recall: 0.9831 - precision: 0.9909 - val_loss: 0.0482 - val_dice_coef: 0.9753 - val_jackard_index: 0.9518 - val_auc: 0.9795 - val_recall: 0.9720 - val_precision: 0.9820
#
# Epoch 00029: val_loss did not improve from 0.04815
# Epoch 30/40
# 225/225 [==============================] - 49s 217ms/step - loss: 0.0292 - dice_coef: 0.9852 - jackard_index: 0.9708 - auc: 0.9919 - recall: 0.9832 - precision: 0.9911 - val_loss: 0.0483 - val_dice_coef: 0.9753 - val_jackard_index: 0.9517 - val_auc: 0.9793 - val_recall: 0.9719 - val_precision: 0.9821
#
# Epoch 00030: val_loss did not improve from 0.04815
# Epoch 31/40
# 225/225 [==============================] - 49s 217ms/step - loss: 0.0290 - dice_coef: 0.9853 - jackard_index: 0.9710 - auc: 0.9920 - recall: 0.9831 - precision: 0.9913 - val_loss: 0.0483 - val_dice_coef: 0.9752 - val_jackard_index: 0.9517 - val_auc: 0.9790 - val_recall: 0.9726 - val_precision: 0.9813
#
# Epoch 00031: val_loss did not improve from 0.04815
# Epoch 32/40
# 225/225 [==============================] - 50s 221ms/step - loss: 0.0289 - dice_coef: 0.9854 - jackard_index: 0.9711 - auc: 0.9920 - recall: 0.9834 - precision: 0.9912 - val_loss: 0.0483 - val_dice_coef: 0.9752 - val_jackard_index: 0.9517 - val_auc: 0.9790 - val_recall: 0.9729 - val_precision: 0.9812
#
# Epoch 00032: val_loss did not improve from 0.04815
# Epoch 33/40
# 225/225 [==============================] - 119s 531ms/step - loss: 0.0288 - dice_coef: 0.9854 - jackard_index: 0.9712 - auc: 0.9921 - recall: 0.9834 - precision: 0.9912 - val_loss: 0.0483 - val_dice_coef: 0.9752 - val_jackard_index: 0.9517 - val_auc: 0.9789 - val_recall: 0.9730 - val_precision: 0.9811
#
# Epoch 00033: val_loss did not improve from 0.04815
# Epoch 34/40
# 225/225 [==============================] - 3468s 15s/step - loss: 0.0287 - dice_coef: 0.9854 - jackard_index: 0.9713 - auc: 0.9921 - recall: 0.9835 - precision: 0.9912 - val_loss: 0.0483 - val_dice_coef: 0.9752 - val_jackard_index: 0.9517 - val_auc: 0.9791 - val_recall: 0.9724 - val_precision: 0.9815
#
# Epoch 00034: val_loss did not improve from 0.04815
# Epoch 35/40
# 225/225 [==============================] - 251s 1s/step - loss: 0.0287 - dice_coef: 0.9854 - jackard_index: 0.9713 - auc: 0.9921 - recall: 0.9835 - precision: 0.9912 - val_loss: 0.0483 - val_dice_coef: 0.9752 - val_jackard_index: 0.9517 - val_auc: 0.9792 - val_recall: 0.9723 - val_precision: 0.9816
#
# Epoch 00035: val_loss did not improve from 0.04815
# Epoch 36/40
# 225/225 [==============================] - 51s 229ms/step - loss: 0.0287 - dice_coef: 0.9854 - jackard_index: 0.9713 - auc: 0.9921 - recall: 0.9835 - precision: 0.9912 - val_loss: 0.0483 - val_dice_coef: 0.9752 - val_jackard_index: 0.9517 - val_auc: 0.9792 - val_recall: 0.9723 - val_precision: 0.9816
#
# Epoch 00036: val_loss did not improve from 0.04815
# Epoch 37/40
# 225/225 [==============================] - 51s 224ms/step - loss: 0.0287 - dice_coef: 0.9854 - jackard_index: 0.9713 - auc: 0.9921 - recall: 0.9836 - precision: 0.9912 - val_loss: 0.0483 - val_dice_coef: 0.9752 - val_jackard_index: 0.9517 - val_auc: 0.9792 - val_recall: 0.9723 - val_precision: 0.9816
#
# Epoch 00037: val_loss did not improve from 0.04815

# %%
model.load_weights('./output/unet_weights.27.0.05.hdf5')
model.compile(loss = dice_loss, optimizer=opt, metrics=metrics)

# %%
test_x, test_y= load_data(path='./dataset/LSP/test/',mode='testing')
test_dataset = tf_dataset(test_x, test_y, batch=BATCH)

print("test data: ", len(test_x))
test_steps = (len(test_x)//BATCH)
if len(test_x) % BATCH != 0:
    test_steps += 1
# Out:
# test data:  138

# %%
def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = np.expand_dims(x, axis=-1)
    x = x/255.0
    return x

# %%
def mask_parse(mask):
    mask = np.squeeze(mask)
    mask = [mask, mask, mask]
    mask = np.transpose(mask, (1, 2, 0))
    return mask

# %%
for i, (x, y) in enumerate(zip(test_x[:10], test_y[:10])):
    x = read_image(x)
    y = read_mask(y)
    
    y_pred = model.predict(np.expand_dims(x, axis=0))[0] > 0.5
    
    h, w, _ = x.shape
    white_line = np.ones((h, 10, 3))

    all_images = [
        x, white_line,
        mask_parse(y), white_line,
        mask_parse(y_pred)
    ]
    image = np.concatenate(all_images, axis=1)
    
    yp = np.where(y_pred == True, 1.0, 0.0)
    fig = plt.figure(figsize=(12, 12)) 
    a = fig.add_subplot(1, 1, 1)
    a.axes.set_title('DC:{:.3f} JI:{:.3f}'.format(dice_coef(y,yp),jackard_index(y,yp)))
    imgplot = plt.imshow(image)
# Out:
# 2022-09-06 18:25:23.395442: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
dicecoef=0
jackardindex=0
for  i, (x, y) in enumerate(zip(test_x, test_y)):
    x = read_image(x)
    y = read_mask(y)
    y_pred = model.predict(np.expand_dims(x, axis=0))[0] > 0.5
    yp = np.where(y_pred == True, 1.0, 0.0)
    

    dicecoef += dice_coef(y,yp)
    jackardindex += jackard_index(y,yp)
    
print('DC:{:.3f} JI:{:.3f}'.format(dicecoef/138,jackardindex/138))
# Out:
# DC:0.971 JI:0.945
