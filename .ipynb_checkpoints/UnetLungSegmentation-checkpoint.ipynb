# %% [markdown]
# # Lung Segmentation

# %% [markdown]
# ## import all packages

# %%
import os
import datetime
import time
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Conv2D, Activation, BatchNormalization,MaxPooling2D,Dense,concatenate
from tensorflow.keras.layers import UpSampling2D, Input, Concatenate,Conv2DTranspose
from tensorflow.keras.layers import Input,UpSampling3D,Dense, Dropout,BatchNormalization, Activation
from tensorflow.keras.layers import GlobalAveragePooling2D, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint,LearningRateScheduler
from tensorflow.keras.metrics import Recall, Precision,MeanIoU,AUC
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
# Out:
# /Users/user/miniforge3/envs/Apple/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
IMAGE_SIZE = 256
EPOCHS = 50
BATCH = 4
LR = 1e-4

PATH = './dataset/LSP/train/'

# %% [markdown]
# # Load dataset

# %%
def load_data(path='../dataset/LSP/train/', split=0.1,mode=''):
    images = sorted(glob(os.path.join(path, "images/*")))
    masks = sorted(glob(os.path.join(path, "masks/*")))
    
    if mode == 'training':
        total_size = len(images)
        valid_size = int(split * total_size)
        train_x, valid_x = train_test_split(images, test_size=valid_size, random_state=42)
        train_y, valid_y = train_test_split(masks, test_size=valid_size, random_state=42)

        return (train_x, train_y), (valid_x, valid_y)
    
    if mode == 'testing':
        return (images,masks)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (256, 256))
    x = x/255.0
    x = np.expand_dims(x, axis=-1)
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
    x.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    y.set_shape([256, 256, 1])
    return x, y

def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
#     dataset = dataset.repeat()
    return dataset

# %%
(train_x, train_y), (valid_x, valid_y) = load_data(PATH,mode='training')

print("Training data: ", len(train_x))
print("Validation data: ", len(valid_x))
# Out:
# Training data:  1359
# Validation data:  150

# %%
def read_and_rgb(x):
    x = cv2.imread(x)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    return x

# %%
fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(valid_x[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(valid_x[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(valid_x[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(valid_x[3]))
imgplot.set_clim(0.0, 2.1)

fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(read_and_rgb(valid_y[0]))

a = fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(read_and_rgb(valid_y[1]))
imgplot.set_clim(0.0, 0.7)

a = fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(read_and_rgb(valid_y[2]))
imgplot.set_clim(0.0, 1.4)

a = fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(read_and_rgb(valid_y[3]))
imgplot.set_clim(0.0, 1.4)

# %% [markdown]
# ## load pretrained model from tensorflow

# %%
def build_model(inputs):
    mobilenetv2 = tf.keras.applications.MobileNetV2(
        input_tensor = inputs, 
        weights="imagenet", include_top=False, alpha=0.35)
    mobilenetv2.trainable = False
    x = mobilenetv2.get_layer('out_relu').output
    x = Conv2D(128,3,name='final_conv',padding='same',activation='relu')(x)
    x = GlobalAveragePooling2D(name='gap')(x)
    output = Dense(2,activation='sigmoid')(x)
    return tf.keras.Model(inputs,output)

# %% [markdown]
# # build unet from the pretrained model
#
# https://github.com/nikhilroxtomar/Unet-with-Pretrained-Encoder/blob/master/U-Net_with_Pretrained_MobileNetV2_as_Encoder.ipynb?ref=morioh.com&utm_source=morioh.com
#
# ![image](https://github.com/nikhilroxtomar/Unet-with-Pretrained-Encoder/raw/5898a1e1ee66df875239d679839a30e419b20375//images/u-net-architecture.png)

# %%
def model():
    inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")
    
    encoder = build_model(inputs)
#     encoder.load_weights('../../output/checkpoints/mobilenetv2/512_128weights.16-0.31.hdf5')
    skip_connection_names = ["input_image","block_1_expand_relu", "block_3_expand_relu", "block_6_expand_relu"]
    encoder_output = encoder.get_layer("block_13_expand_relu").output
    f = [ 16, 32, 48, 64]
    x = encoder_output
    for i in range(1, len(skip_connection_names)+1, 1):
        x_skip = encoder.get_layer(skip_connection_names[-i]).output
        x = Conv2DTranspose(filters=f[-i],kernel_size=3,strides=2,padding='same')(x)
        x = Concatenate()([x, x_skip])
        
        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        
        x = Conv2D(f[-i], (3, 3), padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        
    x = Conv2D(1, (1, 1), padding="same")(x)
    x = Activation("sigmoid")(x)
    
    model = Model(inputs, x)
    
    return model

# %% [markdown]
# ![image](https://miro.medium.com/max/700/1*PqtyWOC9StSUBFw1SLMe4g.png)

# %%
# def unet_plus_plus():
#     return

# %%
model = model()
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Metal device set to: Apple M1
# 2022-08-22 13:18:42.145702: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-08-22 13:18:42.145789: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 128, 128, 16) 432         input_image[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 128, 128, 16) 64          Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 128, 128, 16) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 128, 128, 16) 144         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 128, 128, 16) 64          expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 128, 128, 16) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 128, 128, 8)  128         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 128, 128, 8)  32          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 128, 128, 48) 384         expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 128, 128, 48) 192         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 128, 128, 48) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 129, 129, 48) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 64, 64, 48)   432         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 64, 64, 48)   192         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 64, 64, 48)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 64, 64, 8)    384         block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 64, 64, 8)    32          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 64, 64, 48)   384         block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 64, 64, 48)   192         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 64, 64, 48)   0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 64, 64, 48)   432         block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 64, 64, 48)   192         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 64, 64, 48)   0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 64, 64, 8)    384         block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 64, 64, 8)    32          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 64, 64, 8)    0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 64, 64, 48)   384         block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 64, 64, 48)   192         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 64, 64, 48)   0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 65, 65, 48)   0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 32, 32, 48)   432         block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 32, 32, 48)   192         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 32, 32, 48)   0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 32, 32, 16)   768         block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 32, 32, 16)   64          block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 32, 32, 96)   1536        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 32, 32, 96)   384         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 32, 32, 96)   0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 32, 32, 96)   864         block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 32, 32, 96)   384         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 32, 32, 96)   0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 32, 32, 16)   1536        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 32, 32, 16)   64          block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 32, 32, 16)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 32, 32, 96)   1536        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 32, 32, 96)   384         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 32, 32, 96)   0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 32, 32, 96)   864         block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 32, 32, 96)   384         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 32, 32, 96)   0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 32, 32, 16)   1536        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 32, 32, 16)   64          block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 32, 32, 16)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 32, 32, 96)   1536        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 32, 32, 96)   384         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 32, 32, 96)   0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 33, 33, 96)   0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 16, 16, 96)   864         block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 16, 16, 96)   384         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 16, 16, 96)   0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 16, 16, 24)   2304        block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 16, 16, 24)   96          block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 16, 16, 144)  3456        block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 16, 16, 144)  576         block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 16, 16, 144)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 16, 16, 144)  1296        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 16, 16, 144)  576         block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 16, 16, 144)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 16, 16, 24)   3456        block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 16, 16, 24)   96          block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 16, 16, 24)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 16, 16, 144)  3456        block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 16, 16, 144)  576         block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 16, 16, 144)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 16, 16, 144)  1296        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 16, 16, 144)  576         block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 16, 16, 144)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 16, 16, 24)   3456        block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 16, 16, 24)   96          block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 16, 16, 24)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 16, 16, 144)  3456        block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 16, 16, 144)  576         block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 16, 16, 144)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 16, 16, 144)  1296        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 16, 16, 144)  576         block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 16, 16, 144)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 16, 16, 24)   3456        block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 16, 16, 24)   96          block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 16, 16, 24)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 16, 16, 144)  3456        block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 16, 16, 144)  576         block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 16, 16, 144)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 16, 16, 144)  1296        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 16, 16, 144)  576         block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 16, 16, 144)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 16, 16, 32)   4608        block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 16, 16, 32)   128         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 16, 16, 192)  6144        block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 16, 16, 192)  768         block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 16, 16, 192)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 16, 16, 192)  1728        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 16, 16, 192)  768         block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 16, 16, 192)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 16, 16, 32)   6144        block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 16, 16, 32)   128         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 16, 16, 32)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 16, 16, 192)  6144        block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 16, 16, 192)  768         block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 16, 16, 192)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 16, 16, 192)  1728        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 16, 16, 192)  768         block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 16, 16, 192)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 16, 16, 32)   6144        block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 16, 16, 32)   128         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 16, 16, 32)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 16, 16, 192)  6144        block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 16, 16, 192)  768         block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 16, 16, 192)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 64)   110656      block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 160)  0           conv2d_transpose[0][0]
#                                                                  block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   92224       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 48)   27696       activation_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 96)   0           conv2d_transpose_1[0][0]
#                                                                  block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 48)   41520       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 48)   192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 48)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 48)   20784       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 48)   192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 48)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 32) 13856       activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 80) 0           conv2d_transpose_2[0][0]
#                                                                  block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 32) 23072       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 32) 128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128, 128, 32) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 32) 9248        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 32) 128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 32) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 16) 4624        activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 19) 0           conv2d_transpose_3[0][0]
#                                                                  input_image[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 256, 16) 2752        concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 256, 256, 16) 64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 256, 256, 16) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 16) 2320        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 256, 256, 16) 64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 256, 256, 16) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 1)  17          activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256, 256, 1)  0           conv2d_8[0][0]
# ==================================================================================================
# Total params: 485,489
# Trainable params: 386,337
# Non-trainable params: 99,152
# __________________________________________________________________________________________________

# %% [markdown]
# ## Define Evaluatoin Metrics

# %%
smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def jackard_index(y_true, y_pred):
    
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) -intersection + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)
def jackard_index_loss(y_true, y_pred):
    return 1.0 - jackard_index(y_true, y_pred)

# %%
train_dataset = tf_dataset(train_x, train_y, batch=BATCH)
valid_dataset = tf_dataset(valid_x, valid_y, batch=BATCH)

# %%
opt = tf.keras.optimizers.Nadam(LR)
metrics = [dice_coef, jackard_index, AUC(curve='PR'), Recall(), Precision()]
# model.load_weights('./output/unet_weights.19.0.03.hdf5')
model.compile(loss = jackard_index_loss, optimizer=opt, metrics=metrics)

# %%
log_dir = "logs/unet/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3),
    tf.keras.callbacks.TensorBoard(log_dir=log_dir),
    ModelCheckpoint(
        './output/unet_weights.{epoch:02d}.{val_loss:.2f}.hdf5',
        monitor='val_loss',save_best_only=True,save_weights_only=True,verbose=1),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False)
]
# Out:
# 2022-08-22 13:18:42.879028: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session initializing.
# 2022-08-22 13:18:42.879036: I tensorflow/core/profiler/lib/profiler_session.cc:141] Profiler session started.
# 2022-08-22 13:18:42.879065: I tensorflow/core/profiler/lib/profiler_session.cc:159] Profiler session tear down.

# %%
train_steps = len(train_x)//BATCH
valid_steps = len(valid_x)//BATCH

if len(train_x) % BATCH != 0:
    train_steps += 1
if len(valid_x) % BATCH != 0:
    valid_steps += 1

model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=40,
    steps_per_epoch=train_steps,
    validation_steps=valid_steps,
    callbacks=callbacks
)
# Out:
# /Users/user/miniforge3/envs/Apple/lib/python3.9/site-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# 2022-08-22 13:18:43.107941: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-08-22 13:18:43.108284: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/40
# 2022-08-22 13:18:44.340363: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
#   1/340 [..............................] - ETA: 13:40 - loss: 0.7371 - dice_coef: 0.4164 - jackard_index: 0.2629 - auc: 0.3695 - recall: 0.6370 - precision: 0.3592
# 2022-08-22 13:18:45.597731: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session initializing.
# 2022-08-22 13:18:45.597743: I tensorflow/core/profiler/lib/profiler_session.cc:141] Profiler session started.
#   2/340 [..............................] - ETA: 1:33 - loss: 0.7404 - dice_coef: 0.4122 - jackard_index: 0.2596 - auc: 0.3458 - recall: 0.6174 - precision: 0.3547
# 2022-08-22 13:18:45.812337: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-08-22 13:18:45.817152: I tensorflow/core/profiler/lib/profiler_session.cc:159] Profiler session tear down.
# 2022-08-22 13:18:45.822034: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs/unet/20220822-131842/train/plugins/profile/2022_08_22_13_18_45
# 2022-08-22 13:18:45.824056: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for trace.json.gz to logs/unet/20220822-131842/train/plugins/profile/2022_08_22_13_18_45/users-MacBook-Pro.local.trace.json.gz
# 2022-08-22 13:18:45.828624: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs/unet/20220822-131842/train/plugins/profile/2022_08_22_13_18_45
# 2022-08-22 13:18:45.828883: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for memory_profile.json.gz to logs/unet/20220822-131842/train/plugins/profile/2022_08_22_13_18_45/users-MacBook-Pro.local.memory_profile.json.gz
# 2022-08-22 13:18:45.829308: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: logs/unet/20220822-131842/train/plugins/profile/2022_08_22_13_18_45Dumped tool data for xplane.pb to logs/unet/20220822-131842/train/plugins/profile/2022_08_22_13_18_45/users-MacBook-Pro.local.xplane.pb
# Dumped tool data for overview_page.pb to logs/unet/20220822-131842/train/plugins/profile/2022_08_22_13_18_45/users-MacBook-Pro.local.overview_page.pb
# Dumped tool data for input_pipeline.pb to logs/unet/20220822-131842/train/plugins/profile/2022_08_22_13_18_45/users-MacBook-Pro.local.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to logs/unet/20220822-131842/train/plugins/profile/2022_08_22_13_18_45/users-MacBook-Pro.local.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to logs/unet/20220822-131842/train/plugins/profile/2022_08_22_13_18_45/users-MacBook-Pro.local.kernel_stats.pb
# 340/340 [==============================] - ETA: 0s - loss: 0.3342 - dice_coef: 0.7894 - jackard_index: 0.6659 - auc: 0.9688 - recall: 0.9503 - precision: 0.8417
# 2022-08-22 13:20:42.772825: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 340/340 [==============================] - 133s 385ms/step - loss: 0.3342 - dice_coef: 0.7894 - jackard_index: 0.6659 - auc: 0.9688 - recall: 0.9503 - precision: 0.8417 - val_loss: 0.2991 - val_dice_coef: 0.8230 - val_jackard_index: 0.7003 - val_auc: 0.9894 - val_recall: 0.9715 - val_precision: 0.9454
#
# Epoch 00001: val_loss improved from inf to 0.29906, saving model to ./output/unet_weights.01.0.30.hdf5
# Epoch 2/40
# 340/340 [==============================] - 130s 381ms/step - loss: 0.2087 - dice_coef: 0.8827 - jackard_index: 0.7913 - auc: 0.9851 - recall: 0.9726 - precision: 0.9464 - val_loss: 0.1879 - val_dice_coef: 0.8955 - val_jackard_index: 0.8113 - val_auc: 0.9876 - val_recall: 0.9618 - val_precision: 0.9676
#
# Epoch 00002: val_loss improved from 0.29906 to 0.18790, saving model to ./output/unet_weights.02.0.19.hdf5
# Epoch 3/40
# 340/340 [==============================] - 129s 378ms/step - loss: 0.1654 - dice_coef: 0.9093 - jackard_index: 0.8346 - auc: 0.9830 - recall: 0.9717 - precision: 0.9570 - val_loss: 0.1524 - val_dice_coef: 0.9168 - val_jackard_index: 0.8469 - val_auc: 0.9834 - val_recall: 0.9700 - val_precision: 0.9607
#
# Epoch 00003: val_loss improved from 0.18790 to 0.15237, saving model to ./output/unet_weights.03.0.15.hdf5
# Epoch 4/40
# 340/340 [==============================] - 129s 380ms/step - loss: 0.1359 - dice_coef: 0.9267 - jackard_index: 0.8641 - auc: 0.9824 - recall: 0.9711 - precision: 0.9627 - val_loss: 0.1294 - val_dice_coef: 0.9302 - val_jackard_index: 0.8698 - val_auc: 0.9814 - val_recall: 0.9713 - val_precision: 0.9614
#
# Epoch 00004: val_loss improved from 0.15237 to 0.12942, saving model to ./output/unet_weights.04.0.13.hdf5
# Epoch 5/40
# 340/340 [==============================] - 129s 378ms/step - loss: 0.1148 - dice_coef: 0.9388 - jackard_index: 0.8852 - auc: 0.9821 - recall: 0.9709 - precision: 0.9664 - val_loss: 0.1139 - val_dice_coef: 0.9390 - val_jackard_index: 0.8854 - val_auc: 0.9784 - val_recall: 0.9702 - val_precision: 0.9603
#
# Epoch 00005: val_loss improved from 0.12942 to 0.11387, saving model to ./output/unet_weights.05.0.11.hdf5
# Epoch 6/40
# 340/340 [==============================] - 133s 390ms/step - loss: 0.0995 - dice_coef: 0.9474 - jackard_index: 0.9005 - auc: 0.9818 - recall: 0.9709 - precision: 0.9690 - val_loss: 0.1013 - val_dice_coef: 0.9461 - val_jackard_index: 0.8980 - val_auc: 0.9774 - val_recall: 0.9701 - val_precision: 0.9627
#
# Epoch 00006: val_loss improved from 0.11387 to 0.10129, saving model to ./output/unet_weights.06.0.10.hdf5
# Epoch 7/40
# 340/340 [==============================] - 133s 390ms/step - loss: 0.0884 - dice_coef: 0.9536 - jackard_index: 0.9116 - auc: 0.9815 - recall: 0.9710 - precision: 0.9708 - val_loss: 0.0932 - val_dice_coef: 0.9506 - val_jackard_index: 0.9061 - val_auc: 0.9752 - val_recall: 0.9704 - val_precision: 0.9618
#
# Epoch 00007: val_loss improved from 0.10129 to 0.09324, saving model to ./output/unet_weights.07.0.09.hdf5
# Epoch 8/40
# 340/340 [==============================] - 131s 385ms/step - loss: 0.0801 - dice_coef: 0.9581 - jackard_index: 0.9200 - auc: 0.9812 - recall: 0.9710 - precision: 0.9722 - val_loss: 0.0868 - val_dice_coef: 0.9541 - val_jackard_index: 0.9125 - val_auc: 0.9751 - val_recall: 0.9688 - val_precision: 0.9634
#
# Epoch 00008: val_loss improved from 0.09324 to 0.08680, saving model to ./output/unet_weights.08.0.09.hdf5
# Epoch 9/40
# 340/340 [==============================] - 131s 384ms/step - loss: 0.0740 - dice_coef: 0.9614 - jackard_index: 0.9260 - auc: 0.9807 - recall: 0.9709 - precision: 0.9733 - val_loss: 0.0810 - val_dice_coef: 0.9572 - val_jackard_index: 0.9182 - val_auc: 0.9768 - val_recall: 0.9611 - val_precision: 0.9722
#
# Epoch 00009: val_loss improved from 0.08680 to 0.08099, saving model to ./output/unet_weights.09.0.08.hdf5
# Epoch 10/40
# 340/340 [==============================] - 132s 388ms/step - loss: 0.0690 - dice_coef: 0.9641 - jackard_index: 0.9310 - auc: 0.9807 - recall: 0.9711 - precision: 0.9743 - val_loss: 0.0762 - val_dice_coef: 0.9598 - val_jackard_index: 0.9231 - val_auc: 0.9736 - val_recall: 0.9705 - val_precision: 0.9656
#
# Epoch 00010: val_loss improved from 0.08099 to 0.07617, saving model to ./output/unet_weights.10.0.08.hdf5
# Epoch 11/40
# 340/340 [==============================] - 131s 385ms/step - loss: 0.0647 - dice_coef: 0.9664 - jackard_index: 0.9353 - auc: 0.9804 - recall: 0.9715 - precision: 0.9753 - val_loss: 0.0734 - val_dice_coef: 0.9613 - val_jackard_index: 0.9258 - val_auc: 0.9734 - val_recall: 0.9711 - val_precision: 0.9652
#
# Epoch 00011: val_loss improved from 0.07617 to 0.07339, saving model to ./output/unet_weights.11.0.07.hdf5
# Epoch 12/40
# 340/340 [==============================] - 130s 383ms/step - loss: 0.0616 - dice_coef: 0.9681 - jackard_index: 0.9384 - auc: 0.9800 - recall: 0.9717 - precision: 0.9758 - val_loss: 0.0731 - val_dice_coef: 0.9616 - val_jackard_index: 0.9262 - val_auc: 0.9703 - val_recall: 0.9734 - val_precision: 0.9614
#
# Epoch 00012: val_loss improved from 0.07339 to 0.07314, saving model to ./output/unet_weights.12.0.07.hdf5
# Epoch 13/40
# 340/340 [==============================] - 130s 381ms/step - loss: 0.0587 - dice_coef: 0.9697 - jackard_index: 0.9413 - auc: 0.9802 - recall: 0.9721 - precision: 0.9766 - val_loss: 0.0766 - val_dice_coef: 0.9598 - val_jackard_index: 0.9230 - val_auc: 0.9659 - val_recall: 0.9706 - val_precision: 0.9586
#
# Epoch 00013: val_loss did not improve from 0.07314
# Epoch 14/40
# 340/340 [==============================] - 129s 379ms/step - loss: 0.0565 - dice_coef: 0.9709 - jackard_index: 0.9435 - auc: 0.9800 - recall: 0.9723 - precision: 0.9772 - val_loss: 0.0723 - val_dice_coef: 0.9621 - val_jackard_index: 0.9272 - val_auc: 0.9671 - val_recall: 0.9699 - val_precision: 0.9624
#
# Epoch 00014: val_loss improved from 0.07314 to 0.07225, saving model to ./output/unet_weights.14.0.07.hdf5
# Epoch 15/40
# 340/340 [==============================] - 130s 382ms/step - loss: 0.0549 - dice_coef: 0.9717 - jackard_index: 0.9451 - auc: 0.9795 - recall: 0.9724 - precision: 0.9776 - val_loss: 0.0677 - val_dice_coef: 0.9644 - val_jackard_index: 0.9316 - val_auc: 0.9713 - val_recall: 0.9637 - val_precision: 0.9720
#
# Epoch 00015: val_loss improved from 0.07225 to 0.06770, saving model to ./output/unet_weights.15.0.07.hdf5
# Epoch 16/40
# 340/340 [==============================] - 130s 380ms/step - loss: 0.0529 - dice_coef: 0.9728 - jackard_index: 0.9471 - auc: 0.9794 - recall: 0.9728 - precision: 0.9782 - val_loss: 0.0707 - val_dice_coef: 0.9629 - val_jackard_index: 0.9287 - val_auc: 0.9648 - val_recall: 0.9713 - val_precision: 0.9611
#
# Epoch 00016: val_loss did not improve from 0.06770
# Epoch 17/40
# 340/340 [==============================] - 130s 382ms/step - loss: 0.0512 - dice_coef: 0.9736 - jackard_index: 0.9488 - auc: 0.9793 - recall: 0.9732 - precision: 0.9788 - val_loss: 0.0795 - val_dice_coef: 0.9582 - val_jackard_index: 0.9202 - val_auc: 0.9550 - val_recall: 0.9722 - val_precision: 0.9504
#
# Epoch 00017: val_loss did not improve from 0.06770
# Epoch 18/40
# 340/340 [==============================] - 131s 385ms/step - loss: 0.0500 - dice_coef: 0.9743 - jackard_index: 0.9500 - auc: 0.9789 - recall: 0.9736 - precision: 0.9791 - val_loss: 0.0760 - val_dice_coef: 0.9601 - val_jackard_index: 0.9236 - val_auc: 0.9553 - val_recall: 0.9749 - val_precision: 0.9512
#
# Epoch 00018: val_loss did not improve from 0.06770
# Epoch 19/40
# 340/340 [==============================] - 130s 381ms/step - loss: 0.0485 - dice_coef: 0.9751 - jackard_index: 0.9515 - auc: 0.9797 - recall: 0.9739 - precision: 0.9800 - val_loss: 0.0650 - val_dice_coef: 0.9659 - val_jackard_index: 0.9344 - val_auc: 0.9680 - val_recall: 0.9673 - val_precision: 0.9694
#
# Epoch 00019: val_loss improved from 0.06770 to 0.06496, saving model to ./output/unet_weights.19.0.06.hdf5
# Epoch 20/40
# 340/340 [==============================] - 130s 382ms/step - loss: 0.0479 - dice_coef: 0.9754 - jackard_index: 0.9521 - auc: 0.9799 - recall: 0.9743 - precision: 0.9802 - val_loss: 0.0652 - val_dice_coef: 0.9658 - val_jackard_index: 0.9341 - val_auc: 0.9673 - val_recall: 0.9684 - val_precision: 0.9680
#
# Epoch 00020: val_loss did not improve from 0.06496
# Epoch 21/40
# 340/340 [==============================] - 131s 385ms/step - loss: 0.0475 - dice_coef: 0.9756 - jackard_index: 0.9525 - auc: 0.9800 - recall: 0.9744 - precision: 0.9804 - val_loss: 0.0651 - val_dice_coef: 0.9658 - val_jackard_index: 0.9342 - val_auc: 0.9672 - val_recall: 0.9684 - val_precision: 0.9681
#
# Epoch 00021: val_loss did not improve from 0.06496
# Epoch 22/40
# 340/340 [==============================] - 130s 382ms/step - loss: 0.0472 - dice_coef: 0.9758 - jackard_index: 0.9528 - auc: 0.9801 - recall: 0.9746 - precision: 0.9806 - val_loss: 0.0651 - val_dice_coef: 0.9659 - val_jackard_index: 0.9343 - val_auc: 0.9671 - val_recall: 0.9684 - val_precision: 0.9680
#
# Epoch 00022: val_loss did not improve from 0.06496
# Epoch 23/40
# 340/340 [==============================] - 131s 383ms/step - loss: 0.0470 - dice_coef: 0.9759 - jackard_index: 0.9530 - auc: 0.9801 - recall: 0.9748 - precision: 0.9805 - val_loss: 0.0633 - val_dice_coef: 0.9667 - val_jackard_index: 0.9359 - val_auc: 0.9689 - val_recall: 0.9675 - val_precision: 0.9707
#
# Epoch 00023: val_loss improved from 0.06496 to 0.06333, saving model to ./output/unet_weights.23.0.06.hdf5
# Epoch 24/40
# 340/340 [==============================] - 132s 387ms/step - loss: 0.0467 - dice_coef: 0.9760 - jackard_index: 0.9533 - auc: 0.9803 - recall: 0.9747 - precision: 0.9808 - val_loss: 0.0633 - val_dice_coef: 0.9668 - val_jackard_index: 0.9360 - val_auc: 0.9689 - val_recall: 0.9675 - val_precision: 0.9708
#
# Epoch 00024: val_loss improved from 0.06333 to 0.06328, saving model to ./output/unet_weights.24.0.06.hdf5
# Epoch 25/40
# 340/340 [==============================] - 131s 384ms/step - loss: 0.0467 - dice_coef: 0.9760 - jackard_index: 0.9533 - auc: 0.9803 - recall: 0.9747 - precision: 0.9809 - val_loss: 0.0633 - val_dice_coef: 0.9668 - val_jackard_index: 0.9360 - val_auc: 0.9689 - val_recall: 0.9675 - val_precision: 0.9708
#
# Epoch 00025: val_loss improved from 0.06328 to 0.06326, saving model to ./output/unet_weights.25.0.06.hdf5
# Epoch 26/40
# 340/340 [==============================] - 130s 381ms/step - loss: 0.0466 - dice_coef: 0.9761 - jackard_index: 0.9534 - auc: 0.9803 - recall: 0.9747 - precision: 0.9809 - val_loss: 0.0633 - val_dice_coef: 0.9668 - val_jackard_index: 0.9360 - val_auc: 0.9689 - val_recall: 0.9674 - val_precision: 0.9708
#
# Epoch 00026: val_loss improved from 0.06326 to 0.06325, saving model to ./output/unet_weights.26.0.06.hdf5
# Epoch 27/40
# 340/340 [==============================] - 130s 382ms/step - loss: 0.0466 - dice_coef: 0.9761 - jackard_index: 0.9534 - auc: 0.9801 - recall: 0.9754 - precision: 0.9803 - val_loss: 0.0631 - val_dice_coef: 0.9668 - val_jackard_index: 0.9361 - val_auc: 0.9690 - val_recall: 0.9674 - val_precision: 0.9709
#
# Epoch 00027: val_loss improved from 0.06325 to 0.06313, saving model to ./output/unet_weights.27.0.06.hdf5
# Epoch 28/40
# 340/340 [==============================] - 130s 383ms/step - loss: 0.0466 - dice_coef: 0.9761 - jackard_index: 0.9534 - auc: 0.9802 - recall: 0.9751 - precision: 0.9806 - val_loss: 0.0631 - val_dice_coef: 0.9669 - val_jackard_index: 0.9362 - val_auc: 0.9691 - val_recall: 0.9672 - val_precision: 0.9712
#
# Epoch 00028: val_loss improved from 0.06313 to 0.06307, saving model to ./output/unet_weights.28.0.06.hdf5
# Epoch 29/40
# 340/340 [==============================] - 130s 383ms/step - loss: 0.0466 - dice_coef: 0.9761 - jackard_index: 0.9534 - auc: 0.9803 - recall: 0.9749 - precision: 0.9807 - val_loss: 0.0630 - val_dice_coef: 0.9669 - val_jackard_index: 0.9362 - val_auc: 0.9692 - val_recall: 0.9671 - val_precision: 0.9714
#
# Epoch 00029: val_loss improved from 0.06307 to 0.06304, saving model to ./output/unet_weights.29.0.06.hdf5
# Epoch 30/40
# 340/340 [==============================] - 130s 382ms/step - loss: 0.0466 - dice_coef: 0.9761 - jackard_index: 0.9534 - auc: 0.9803 - recall: 0.9749 - precision: 0.9808 - val_loss: 0.0630 - val_dice_coef: 0.9669 - val_jackard_index: 0.9362 - val_auc: 0.9692 - val_recall: 0.9670 - val_precision: 0.9715
#
# Epoch 00030: val_loss improved from 0.06304 to 0.06302, saving model to ./output/unet_weights.30.0.06.hdf5
# Epoch 31/40
# 340/340 [==============================] - 129s 379ms/step - loss: 0.0466 - dice_coef: 0.9761 - jackard_index: 0.9535 - auc: 0.9804 - recall: 0.9748 - precision: 0.9809 - val_loss: 0.0630 - val_dice_coef: 0.9669 - val_jackard_index: 0.9362 - val_auc: 0.9693 - val_recall: 0.9669 - val_precision: 0.9715
#
# Epoch 00031: val_loss improved from 0.06302 to 0.06301, saving model to ./output/unet_weights.31.0.06.hdf5
# Epoch 32/40
# 340/340 [==============================] - 129s 379ms/step - loss: 0.0465 - dice_coef: 0.9761 - jackard_index: 0.9535 - auc: 0.9804 - recall: 0.9748 - precision: 0.9809 - val_loss: 0.0630 - val_dice_coef: 0.9669 - val_jackard_index: 0.9362 - val_auc: 0.9693 - val_recall: 0.9669 - val_precision: 0.9716
#
# Epoch 00032: val_loss improved from 0.06301 to 0.06300, saving model to ./output/unet_weights.32.0.06.hdf5
# Epoch 33/40
# 340/340 [==============================] - 129s 380ms/step - loss: 0.0465 - dice_coef: 0.9761 - jackard_index: 0.9535 - auc: 0.9804 - recall: 0.9748 - precision: 0.9809 - val_loss: 0.0630 - val_dice_coef: 0.9669 - val_jackard_index: 0.9362 - val_auc: 0.9693 - val_recall: 0.9669 - val_precision: 0.9716
#
# Epoch 00033: val_loss improved from 0.06300 to 0.06300, saving model to ./output/unet_weights.33.0.06.hdf5
# Epoch 34/40
# 340/340 [==============================] - 131s 385ms/step - loss: 0.0465 - dice_coef: 0.9761 - jackard_index: 0.9535 - auc: 0.9803 - recall: 0.9749 - precision: 0.9808 - val_loss: 0.0630 - val_dice_coef: 0.9669 - val_jackard_index: 0.9362 - val_auc: 0.9692 - val_recall: 0.9670 - val_precision: 0.9715
#
# Epoch 00034: val_loss improved from 0.06300 to 0.06299, saving model to ./output/unet_weights.34.0.06.hdf5
# Epoch 35/40
# 340/340 [==============================] - 130s 382ms/step - loss: 0.0465 - dice_coef: 0.9761 - jackard_index: 0.9535 - auc: 0.9803 - recall: 0.9749 - precision: 0.9808 - val_loss: 0.0630 - val_dice_coef: 0.9669 - val_jackard_index: 0.9362 - val_auc: 0.9693 - val_recall: 0.9669 - val_precision: 0.9715
#
# Epoch 00035: val_loss improved from 0.06299 to 0.06299, saving model to ./output/unet_weights.35.0.06.hdf5
# Epoch 36/40
# 340/340 [==============================] - 133s 390ms/step - loss: 0.0465 - dice_coef: 0.9761 - jackard_index: 0.9535 - auc: 0.9803 - recall: 0.9749 - precision: 0.9808 - val_loss: 0.0630 - val_dice_coef: 0.9669 - val_jackard_index: 0.9362 - val_auc: 0.9693 - val_recall: 0.9669 - val_precision: 0.9716
#
# Epoch 00036: val_loss improved from 0.06299 to 0.06299, saving model to ./output/unet_weights.36.0.06.hdf5
# Epoch 37/40
# 340/340 [==============================] - 132s 388ms/step - loss: 0.0465 - dice_coef: 0.9761 - jackard_index: 0.9535 - auc: 0.9803 - recall: 0.9749 - precision: 0.9808 - val_loss: 0.0630 - val_dice_coef: 0.9669 - val_jackard_index: 0.9362 - val_auc: 0.9693 - val_recall: 0.9669 - val_precision: 0.9716
#
# Epoch 00037: val_loss improved from 0.06299 to 0.06299, saving model to ./output/unet_weights.37.0.06.hdf5
# Epoch 38/40
# 340/340 [==============================] - 131s 385ms/step - loss: 0.0465 - dice_coef: 0.9761 - jackard_index: 0.9535 - auc: 0.9803 - recall: 0.9749 - precision: 0.9808 - val_loss: 0.0630 - val_dice_coef: 0.9669 - val_jackard_index: 0.9362 - val_auc: 0.9693 - val_recall: 0.9669 - val_precision: 0.9716
#
# Epoch 00038: val_loss improved from 0.06299 to 0.06299, saving model to ./output/unet_weights.38.0.06.hdf5
# Epoch 39/40
# 340/340 [==============================] - 132s 388ms/step - loss: 0.0465 - dice_coef: 0.9761 - jackard_index: 0.9535 - auc: 0.9803 - recall: 0.9749 - precision: 0.9808 - val_loss: 0.0630 - val_dice_coef: 0.9669 - val_jackard_index: 0.9362 - val_auc: 0.9693 - val_recall: 0.9669 - val_precision: 0.9716
#
# Epoch 00039: val_loss did not improve from 0.06299
# Epoch 40/40
# 340/340 [==============================] - 130s 382ms/step - loss: 0.0465 - dice_coef: 0.9761 - jackard_index: 0.9535 - auc: 0.9803 - recall: 0.9749 - precision: 0.9808 - val_loss: 0.0630 - val_dice_coef: 0.9669 - val_jackard_index: 0.9362 - val_auc: 0.9693 - val_recall: 0.9669 - val_precision: 0.9716
#
# Epoch 00040: val_loss improved from 0.06299 to 0.06299, saving model to ./output/unet_weights.40.0.06.hdf5

# %%
model.load_weights('./output/unet_weights.35.0.03.hdf5')
model.compile(loss = dice_loss, optimizer=opt, metrics=metrics)

# %%
test_x, test_y= load_data(path='./dataset/LSP/test/',mode='testing')
test_dataset = tf_dataset(test_x, test_y, batch=BATCH)

print("test data: ", len(test_x))
test_steps = (len(test_x)//BATCH)
if len(test_x) % BATCH != 0:
    test_steps += 1
# Out:
# test data:  138

# %%
def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = x/255.0
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_SIZE, IMAGE_SIZE))
    x = np.expand_dims(x, axis=-1)
    x = x/255.0
    return x

# %%
def mask_parse(mask):
    mask = np.squeeze(mask)
    mask = [mask, mask, mask]
    mask = np.transpose(mask, (1, 2, 0))
    return mask

# %%
for i, (x, y) in enumerate(zip(test_x[:10], test_y[:10])):
    x = read_image(x)
    y = read_mask(y)
    
    y_pred = model.predict(np.expand_dims(x, axis=0))[0] > 0.5
    
    h, w, _ = x.shape
    white_line = np.ones((h, 10, 3))

    all_images = [
        x, white_line,
        mask_parse(y), white_line,
        mask_parse(y_pred)
    ]
    image = np.concatenate(all_images, axis=1)
    
    yp = np.where(y_pred == True, 1.0, 0.0)
    fig = plt.figure(figsize=(12, 12)) 
    a = fig.add_subplot(1, 1, 1)
    a.axes.set_title('DC:{:.3f} JI:{:.3f}'.format(dice_coef(y,yp),jackard_index(y,yp)))
    imgplot = plt.imshow(image)
# Out:
# 2022-08-22 14:45:48.615990: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
dicecoef=0
jackardindex=0
for  i, (x, y) in enumerate(zip(test_x, test_y)):
    x = read_image(x)
    y = read_mask(y)
    y_pred = model.predict(np.expand_dims(x, axis=0))[0] > 0.5
    yp = np.where(y_pred == True, 1.0, 0.0)
    

    dicecoef += dice_coef(y,yp)
    jackardindex += jackard_index(y,yp)
    
print('DC:{:.3f} JI:{:.3f}'.format(dicecoef/138,jackardindex/138))
# Out:
# DC:0.968 JI:0.938

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-10,10,100)

# %%
y = np.power(x,5)+np.power(x,2) + x

# %%
yy = 5*np.power(x,4)+2*x+1
yyy = 20*np.power(x,3)+2
yyyy = 60*np.power(x,2)

# %%
plt.plot(x,y,x,yy,x,yyy)
plt.legend(['or','st','snd'])
plt.show()
